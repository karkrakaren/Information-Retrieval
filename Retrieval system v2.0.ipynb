# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast
from nltk.tokenize import wordpunct_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer

# %% [markdown]
# #### Load in data

# %%
data = pd.read_csv('allerhande_preprocessed.csv', index_col=0)
print(data.head())
data = data.replace('\xad', '')
# Out:
#         id                                title  \
# 0   861106              Vegetarische bonenstoof
# 1   680104                    Frisse limoenroom
# 2   683858  Kalkoenfilet met champignonroomsaus
# 3  1187074       Andijvie met rauwe ham en prei
# 4   660152              Spruiten-rozijnensalade
#
#                                          description        course  \
# 0  ['Stoofgerecht', 'vegetarische', 'balletjes,',...  hoofdgerecht
# 1  ['lekker', 'recept.', 'nagerecht', 'bevat', 'v...     nagerecht
# 2  ['Kidsproof', 'winters', 'recept', 'voor', 'pa...  hoofdgerecht
# 3  ['bijgerecht', 'andijvie,', 'prei,', 'knoflook...    bijgerecht
# 4  ['lekker', 'hollands', 'recept.', 'vegetarisch...    bijgerecht
#
#    recipe_yield                                        ingredients  calories  \
# 0           4.0  ['olijfolie', 'tomatenblokjes', 'bruine bonen'...     410.0
# 1           4.0  ['limoenen', 'slagroom', 'vloeibare honing', '...     290.0
# 2           4.0  ['olijfolie', 'gedroogde rozemarijn', 'champig...     585.0
# 3           4.0  ['olijfolie', 'prei', 'knoflook', 'fijngesnede...     175.0
# 4           4.0  ['sladressing bieslook', 'spruitjes', 'bosui',...     115.0
#
#    protein  carbohydrates   fat  ...  sodium  fiber  cooking_time  rating  \
# 0     21.0           52.0  10.0  ...  1040.0   16.0          15.0     3.0
# 1      8.0           14.0  22.0  ...     NaN    NaN          10.0     3.0
# 2     41.0           58.0  21.0  ...     NaN    NaN          25.0     3.0
# 3      9.0            7.0  11.0  ...   475.0    6.0          15.0     3.0
# 4      1.0           19.0   4.0  ...     NaN    NaN          15.0     3.0
#
#    review_count                                 recipe_instruction  \
# 0         483.0                    Verwarm de oven voor op 200 ºC.
# 1         161.0                                                NaN
# 2         112.0  Kook de spaghetti volgens de aanwijzingen op d...
# 3           8.0  Was de preien en snijd ze in ringen. Snijd de ...
# 4          58.0  Verwijder de buitenste bladeren van de spruite...
#
#                                                tags  \
# 0                ['vegetarisch', ' slank', ' oven']
# 1                                         ['kerst']
# 2  ['italiaans', ' wat eten we vandaag', ' bakken']
# 3       ['glutenvrij', ' lactosevrij', ' hollands']
# 4            ['vegetarisch', ' hollands', ' koken']
#
#                     appliances        main_ingredient                type
# 0  ['ovenschaal (20 x 30 cm)']           bruine bonen        ['stoofpot']
# 1              ['hoge glazen']             limoenroom  ['Type not found']
# 2                           []           kalkoenfilet           ['vlees']
# 3                           []  fijngesneden andijvie           ['vlees']
# 4                           []               rozijnen          ['salade']
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Load in inverted columns and convert to dict

# %%
inverted_ingredients_pd = pd.read_csv('inverted_list_ingredients.csv', header=None, names=['Word', 'Index'])
print(inverted_ingredients_pd.head())
inverted_ingredients_dict = pd.Series(inverted_ingredients_pd.Index.values,index=inverted_ingredients_pd.Word).to_dict()
# Out:
#                 Word             Index
# 0            rosties     [4181, 13447]
# 1    kikkererwtenmel            [2405]
# 2         kipshoarma     [6778, 12197]
# 3  paddenstoelentrio  [82, 8643, 9195]
# 4   knoflookbrooddeg            [2205]

# %%
inverted_tags_pd = pd.read_csv('inverted_list_tags.csv', header=None, names=['Word', 'Index'])
# remove row with value NaN
inverted_tags_pd.drop([0], inplace=True)
print(inverted_tags_pd.head())
inverted_tags_dict = pd.Series(inverted_tags_pd.Index.values,index=inverted_tags_pd.Word).to_dict()
# Out:
#                 Word                                              Index
# 1   zonder vlees/vis  [148, 166, 194, 204, 221, 332, 358, 360, 418, ...
# 2     midden-oosters  [173, 452, 505, 660, 1093, 1294, 1566, 1622, 2...
# 3              pasen  [109, 634, 801, 1045, 1293, 1305, 1559, 1574, ...
# 4              kerst  [1, 5, 11, 32, 34, 38, 41, 53, 77, 81, 82, 90,...
# 5      scandinavisch  [76, 251, 752, 1435, 2113, 3140, 3885, 4739, 5...

# %%
inverted_types_pd = pd.read_csv('inverted_list_types.csv', header=None, names=['Word', 'Index'])
print(inverted_types_pd.head())
inverted_types_dict = pd.Series(inverted_types_pd.Index.values,index=inverted_types_pd.Word).to_dict()
# Out:
#      Word                                              Index
# 0     vis  [6, 8, 25, 42, 72, 131, 151, 180, 187, 188, 21...
# 1  souflé                                     [10029, 15780]
# 2   chili  [250, 262, 270, 313, 521, 580, 727, 761, 763, ...
# 3     wok  [77, 127, 197, 227, 253, 479, 527, 557, 578, 6...
# 4   taart  [12, 31, 43, 49, 59, 67, 120, 185, 201, 241, 2...

# %%
inverted_title_pd = pd.read_csv('inverted_list_title.csv', header=None, names=['Word', 'Index'])
print(inverted_title_pd.head())
# index_nr = []
# for i, word in enumerate(inverted_title_pd['Word']):
#     if type(word) is not str:
#         index_nr.append(i)
print(len(inverted_title_pd['Word']))
# print(index_nr)
inverted_title_pd.drop([6662], inplace=True)
inverted_title_dict = pd.Series(inverted_title_pd.Index.values,index=inverted_title_pd.Word).to_dict()
# Out:
#                   Word                Index
# 0              rosties        [4181, 13562]
# 1  hazelnootcantuccini               [9227]
# 2                  lax               [1331]
# 3           kipshoarma  [7540, 9256, 14042]
# 4        kokosspinazie              [15543]
# 8691

# %% [markdown]
# #### First for only one word in only one inverted column

# %%
# word = str, inverted_column = dict, retrieved_docs = list
def retrieve_inverted_column(word, inverted_column):
    retrieved_docs = []
    for key in inverted_column.keys():
        if word in key:
            retrieved_docs += ast.literal_eval(inverted_column.get(key))
    return list(set(retrieved_docs))

# %% [markdown]
# ## Retrieval system
# - tokenize query, remove all tokens that have len = 1, since these are not words
# - for each word in query, create set of documents containing this word
#     - look through each inverted column to retrieve possible documents
# - get the intersection of the document sets of each word to only retrieve documents with all query words
# - print all retrieved documents

# %%
# query = str, inverted_column = list of dicts?
def retrieve(query, inverted_columns, dataset):
    tokens = word_tokenize(query)
    words = [item for item in tokens if len(item) > 1]
    
    # stemmen
    stemmer = SnowballStemmer("dutch")
    words = [stemmer.stem(y) for y in words]
    
    set_per_word = []
    
    # loop through query words
    for word in words:
        
        # get set of retrieved docs for each word
        retrieved_docs_word = []
        for column in inverted_columns:
            retrieved_docs_word += retrieve_inverted_column(word, column)
        set_per_word.append(set(retrieved_docs_word))
    
    # get intersection of sets for whole query
    retrieved = set_per_word[0]
    for element in set_per_word[1:]:
        retrieved = retrieved.intersection(element)
        
    # print all retrieved recipes
    for index in retrieved:
        print(dataset.iloc[index,:])
        print('\n')
        
    return list(retrieved)

# %%
test1 = retrieve("ijskoffie", [inverted_ingredients_dict, inverted_tags_dict, inverted_types_dict, inverted_title_dict],data)
print(data.iloc[test1[0],1])
# Out:
# id                                                               549844
# title                                           IJskoffie met chocorasp
# description           ['lekker', 'recept.', 'vegetarische', 'nagerec...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients                  ['sterke koffie', 'pure chocolade', 'ijs']
# calories                                                            105
# protein                                                               2
# carbohydrates                                                        12
# fat                                                                   6
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                          5
# rating                                                                3
# review_count                                                         92
# recipe_instruction                                                  NaN
# tags                                                    ['vegetarisch']
# appliances                                            ['4 hoge glazen']
# main_ingredient                                           sterke koffie
# type                                                         ['koffie']
# Name: 3714, dtype: object
#
#
# id                                                               208532
# title                                        IJskoffie met advocaatroom
# description           ['lekker', 'recept.', 'vegetarische', 'nagerec...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['vanillesuiker', 'scharreladvocaat', 'café au...
# calories                                                            325
# protein                                                               5
# carbohydrates                                                        32
# fat                                                                  19
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         10
# rating                                                                3
# review_count                                                         16
# recipe_instruction                                                  NaN
# tags                                                    ['vegetarisch']
# appliances                                                           []
# main_ingredient                                               ijskoffie
# type                                                 ['Type not found']
# Name: 3926, dtype: object
#
#
# id                                                               140226
# title                                                         IJskoffie
# description           ['lekker', 'recept.', 'vegetarische', 'nagerec...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients               ['vanilleroomijs', 'likeur', 'hete espresso']
# calories                                                            NaN
# protein                                                             NaN
# carbohydrates                                                       NaN
# fat                                                                 NaN
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                          5
# rating                                                                2
# review_count                                                         18
# recipe_instruction                                                  NaN
# tags                                          ['kerst', ' vegetarisch']
# appliances                                                           []
# main_ingredient                                               ijskoffie
# type                                                         ['koffie']
# Name: 400, dtype: object
#
#
# id                                                               468752
# title                                        IJskoffie met lobbige room
# description           ['lekker', 'recept.', 'vegetarische', 'nagerec...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['suiker', 'slagroom', 'ijsklontjes', 'koffie'...
# calories                                                            274
# protein                                                               2
# carbohydrates                                                        17
# fat                                                                  22
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         10
# rating                                                                3
# review_count                                                         32
# recipe_instruction                                                  NaN
# tags                                                    ['vegetarisch']
# appliances                                                           []
# main_ingredient                                                  koffie
# type                                                 ['Type not found']
# Name: 13214, dtype: object
#
#
# id                                                               517076
# title                                                         IJskoffie
# description           ['lekker', 'recept.', 'vegetarische', 'nagerec...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['kaneelpoeder', 'chocoladesticks', 'witte bas...
# calories                                                              0
# protein                                                               0
# carbohydrates                                                         0
# fat                                                                   0
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         84
# recipe_instruction                                                  NaN
# tags                                ['kerst', ' vegetarisch', ' slank']
# appliances                                   ['hoge glazen', 'blender']
# main_ingredient                                               ijskoffie
# type                                                         ['koffie']
# Name: 18627, dtype: object
#
#
# IJskoffie met chocorasp

# %% [markdown]
# ## User interface test

# %%
from tkinter import *
from PIL import Image, ImageTk

# %%
def click():
    entered_text = textentry.get()
    output.delete(0.0, END)
    recipes = retrieve(entered_text, [inverted_ingredients_dict, inverted_tags_dict, inverted_types_dict, inverted_title_dict],data)
    for element in recipes:
        output.insert(END, data.iloc[element,1])
        output.insert(END, '\n')
    
window = Tk()
window.title('Recepten zoeker')
window.configure(background='white')

image = Image.open("bestek.png")
photo1 = ImageTk.PhotoImage(Image.open("bestek.png"))
Label(window, image=photo1).grid(row=0, column=0, sticky=E)

Label(window, text="Wat wil je eten vanavond?", font='none 24 bold').grid(row=1,column=0,sticky=E+W)

textentry = Entry(window, width = 35)
textentry.grid(row=3,column=0,sticky=W)

Button(window, text='Zoek recepten', width=13, command=click, bg='red', fg='black', font='none 18 bold').grid(row=3,column=0,sticky=E)

Label(window, text='Gevonden recepten',font='none 18 bold').grid(row=4,column=0,sticky=E+W)

output = Text(window, width=75, height=6, wrap=WORD)
output.grid(row=5,column=0,columnspan=2,sticky=E+W)

window.mainloop()
# Out:
# id                                                               549844
# title                                           IJskoffie met chocorasp
# description           ['lekker', 'recept.', 'vegetarische', 'nagerec...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients                  ['sterke koffie', 'pure chocolade', 'ijs']
# calories                                                            105
# protein                                                               2
# carbohydrates                                                        12
# fat                                                                   6
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                          5
# rating                                                                3
# review_count                                                         92
# recipe_instruction                                                  NaN
# tags                                                    ['vegetarisch']
# appliances                                            ['4 hoge glazen']
# main_ingredient                                           sterke koffie
# type                                                         ['koffie']
# Name: 3714, dtype: object
#
#
# id                                                               208532
# title                                        IJskoffie met advocaatroom
# description           ['lekker', 'recept.', 'vegetarische', 'nagerec...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['vanillesuiker', 'scharreladvocaat', 'café au...
# calories                                                            325
# protein                                                               5
# carbohydrates                                                        32
# fat                                                                  19
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         10
# rating                                                                3
# review_count                                                         16
# recipe_instruction                                                  NaN
# tags                                                    ['vegetarisch']
# appliances                                                           []
# main_ingredient                                               ijskoffie
# type                                                 ['Type not found']
# Name: 3926, dtype: object
#
#
# id                                                               140226
# title                                                         IJskoffie
# description           ['lekker', 'recept.', 'vegetarische', 'nagerec...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients               ['vanilleroomijs', 'likeur', 'hete espresso']
# calories                                                            NaN
# protein                                                             NaN
# carbohydrates                                                       NaN
# fat                                                                 NaN
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                          5
# rating                                                                2
# review_count                                                         18
# recipe_instruction                                                  NaN
# tags                                          ['kerst', ' vegetarisch']
# appliances                                                           []
# main_ingredient                                               ijskoffie
# type                                                         ['koffie']
# Name: 400, dtype: object
#
#
# id                                                               468752
# title                                        IJskoffie met lobbige room
# description           ['lekker', 'recept.', 'vegetarische', 'nagerec...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['suiker', 'slagroom', 'ijsklontjes', 'koffie'...
# calories                                                            274
# protein                                                               2
# carbohydrates                                                        17
# fat                                                                  22
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         10
# rating                                                                3
# review_count                                                         32
# recipe_instruction                                                  NaN
# tags                                                    ['vegetarisch']
# appliances                                                           []
# main_ingredient                                                  koffie
# type                                                 ['Type not found']
# Name: 13214, dtype: object
#
#
# id                                                               517076
# title                                                         IJskoffie
# description           ['lekker', 'recept.', 'vegetarische', 'nagerec...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['kaneelpoeder', 'chocoladesticks', 'witte bas...
# calories                                                              0
# protein                                                               0
# carbohydrates                                                         0
# fat                                                                   0
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         84
# recipe_instruction                                                  NaN
# tags                                ['kerst', ' vegetarisch', ' slank']
# appliances                                   ['hoge glazen', 'blender']
# main_ingredient                                               ijskoffie
# type                                                         ['koffie']
# Name: 18627, dtype: object
#
#
# id                                                              1186438
# title                              Snelle 'risotto' met truffeltapenade
# description           ['In', 'bouillon', 'gekookte', 'rijst', 'champ...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'kokend water', '1 minuut basmat...
# calories                                                            590
# protein                                                              19
# carbohydrates                                                        59
# fat                                                                  29
# saturated_fat                                                        11
# sodium                                                              975
# fiber                                                                 7
# cooking_time                                                         17
# rating                                                                3
# review_count                                                         41
# recipe_instruction    Snijd een stukje van de boven- en onderkant va...
# tags                  ['vegetarisch', ' italiaans', ' wat eten we va...
# appliances                                                           []
# main_ingredient                                                 risotto
# type                                                        ['risotto']
# Name: 4692, dtype: object
#
#
# id                                                               140190
# title                                  Saffraanrisotto met cantharellen
# description           ['lekker', 'italiaans', 'recept.', 'vegetarisc...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['cantharellen of kastanjechampignons', 'kruid...
# calories                                                            880
# protein                                                              23
# carbohydrates                                                        83
# fat                                                                  46
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         40
# rating                                                                3
# review_count                                                         51
# recipe_instruction                                                  NaN
# tags                            ['kerst', ' vegetarisch', ' italiaans']
# appliances                                                           []
# main_ingredient                                                saffraan
# type                                                        ['risotto']
# Name: 4067, dtype: object
#
#
# id                                                               429204
# title                           Kipfilet pesto met paddenstoelenrisotto
# description           ['Makkelijke', 'risotto', 'paddenstoelen,', 'I...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['risotto ai funghi', 'pestokipfilet', 'Italia...
# calories                                                            525
# protein                                                              33
# carbohydrates                                                        58
# fat                                                                  18
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                         91
# recipe_instruction    Bereid de risotto volgens de aanwijzingen op d...
# tags                                           ['italiaans', ' bakken']
# appliances                                                           []
# main_ingredient                                                   pesto
# type                                                          ['vlees']
# Name: 10086, dtype: object
#
#
# id                                                               793620
# title                                    Risotto met ham en champignons
# description           ['Italiaans', 'gerecht', 'rauwe', 'ham', 'kast...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['boter', 'kastanjechampignons', 'bospaddensto...
# calories                                                            560
# protein                                                              26
# carbohydrates                                                        65
# fat                                                                  21
# saturated_fat                                                        13
# sodium                                                             1850
# fiber                                                                 2
# cooking_time                                                         30
# rating                                                                3
# review_count                                                        444
# recipe_instruction    Snijd de courgette in de lengte in vieren. Ver...
# tags                                           ['italiaans', ' bakken']
# appliances                                                           []
# main_ingredient                                                 risotto
# type                                                        ['risotto']
# Name: 1507, dtype: object
#
#
# id                                                              1189960
# title                     Paddenstoelenrisotto met pancetta uit de oven
# description           ['Italiaans', 'gerecht', 'pancetta,', 'risotto...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['crème fraîche', 'boter', 'pancetta', 'kastan...
# calories                                                            595
# protein                                                              21
# carbohydrates                                                        63
# fat                                                                  28
# saturated_fat                                                        17
# sodium                                                             1120
# fiber                                                                 4
# cooking_time                                                         15
# rating                                                                5
# review_count                                                          1
# recipe_instruction    Verwarm de oven voor op 180 °C.  Snijd de panc...
# tags                                  ['budget', ' oven', ' italiaans']
# appliances                             ['lage ovenschaal (20 x 30 cm)']
# main_ingredient                                    paddenstoelenrisotto
# type                                                        ['risotto']
# Name: 3448, dtype: object
#
#
# id                                                               420028
# title                                 Paddenstoelenrisotto met spinazie
# description           ['Risotto', 'kastanjechampignons,', 'verse', '...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'groentebouillon (van tablet)', ...
# calories                                                            590
# protein                                                              25
# carbohydrates                                                        66
# fat                                                                  24
# saturated_fat                                                        11
# sodium                                                             1450
# fiber                                                                 3
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        795
# recipe_instruction    Snipper de ui. Verhit 2/3 van de olie in een h...
# tags                      ['zonder vlees/vis', ' italiaans', ' bakken']
# appliances                                                           []
# main_ingredient                                    paddenstoelenrisotto
# type                                                        ['risotto']
# Name: 2218, dtype: object
#
#
# id                                                               613408
# title                               Paddenstoelenrisotto met geitenkaas
# description           ['Vegetarisch', 'Italiaans', 'gerecht', 'risot...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'geitenkaas', 'witlof', 'risotto...
# calories                                                            535
# protein                                                              20
# carbohydrates                                                        60
# fat                                                                  23
# saturated_fat                                                        12
# sodium                                                              665
# fiber                                                                 3
# cooking_time                                                         30
# rating                                                                3
# review_count                                                        342
# recipe_instruction    Bereid de risotto volgens de aanwijzingen op d...
# tags                  ['vegetarisch', ' italiaans', ' wat eten we va...
# appliances                                                           []
# main_ingredient                                       risotto ai funghi
# type                                                        ['risotto']
# Name: 16125, dtype: object
#
#
# id                                                               409672
# title                                   Risotto met kastanjechampignons
# description           ['Risotto', 'kastanjechampignons,', 'ui,', 'ro...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['kastanjechampignon', 'roomboter', 'rode wijn...
# calories                                                            555
# protein                                                              16
# carbohydrates                                                        63
# fat                                                                  23
# saturated_fat                                                        12
# sodium                                                              810
# fiber                                                                 2
# cooking_time                                                         30
# rating                                                                3
# review_count                                                        325
# recipe_instruction    Snipper de ui en snijd de knoflook fijn. Maak ...
# tags                       ['zonder vlees/vis', ' italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                                 risotto
# type                                                        ['risotto']
# Name: 15936, dtype: object
# id                                                               197388
# title                                                    Rijstkroketjes
# description           ['lekker', 'italiaans', 'recept.', 'vegetarisc...
# course                                                      voorgerecht
# recipe_yield                                                         12
# ingredients           ['witte wijn', 'saffraandraadjes', 'zout', 'ri...
# calories                                                            190
# protein                                                               4
# carbohydrates                                                        17
# fat                                                                  12
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         55
# rating                                                                3
# review_count                                                         25
# recipe_instruction    Ui pellen en fijn snipperen. In pan 3 el boter...
# tags                         ['vegetarisch', ' italiaans', ' frituren']
# appliances                                               ['frituurpan']
# main_ingredient                                          rijstkroketjes
# type                                                          ['vlees']
# Name: 459, dtype: object
#
#
# id                                                               427472
# title                            Gevulde tomaten met mediterrane filets
# description           ['lekker', 'recept.', 'vegetarische', 'hoofdge...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'rucola slamelange', 'azijn', 't...
# calories                                                            530
# protein                                                              22
# carbohydrates                                                        60
# fat                                                                  22
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                2
# review_count                                                         11
# recipe_instruction                                                  NaN
# tags                                         ['vegetarisch', ' bakken']
# appliances                                                           []
# main_ingredient                                                 tomaten
# type                                                        ['risotto']
# Name: 16062, dtype: object
#
#
# id                                                               474992
# title                          Groenterisotto met brie en basilicumolie
# description           ['lekker', 'italiaans', 'recept.', 'vegetarisc...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'Italiaanse', 'roombrie', 'balsa...
# calories                                                            893
# protein                                                              20
# carbohydrates                                                        75
# fat                                                                  57
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                         84
# recipe_instruction                                                  NaN
# tags                            ['vegetarisch', ' italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                          groenterisotto
# type                                                        ['risotto']
# Name: 11767, dtype: object
#
#
# id                                                               839530
# title                      Auberginerisotto met geitenkaas en basilicum
# description           ['lekker', 'italiaans', 'recept.', 'vegetarisc...
# course                                                       bijgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'knoflook', 'groentebouillon', '...
# calories                                                            480
# protein                                                              12
# carbohydrates                                                        64
# fat                                                                  18
# saturated_fat                                                         6
# sodium                                                             1235
# fiber                                                                 4
# cooking_time                                                         30
# rating                                                                3
# review_count                                                        218
# recipe_instruction    Snijd de aubergine in blokjes van 1 x 1 cm. Sn...
# tags                  ['vegetarisch', ' italiaans', ' wat eten we va...
# appliances                                                           []
# main_ingredient                                               aubergine
# type                                                        ['risotto']
# Name: 3896, dtype: object
#
#
# id                                                               479722
# title                                 Kaas-tijmrisotto met tuinboontjes
# description           ['lekker', 'italiaans', 'recept.', 'vegetarisc...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['verse tijm', 'geraspte kaas', 'tuinbonen', '...
# calories                                                            393
# protein                                                              22
# carbohydrates                                                        65
# fat                                                                   5
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                         89
# recipe_instruction                                                  NaN
# tags                            ['vegetarisch', ' italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                              verse tijm
# type                                                        ['risotto']
# Name: 5296, dtype: object
#
#
# id                                                               476614
# title                                                    Olijvenrisotto
# description           ['lekker', 'italiaans', 'recept.', 'vegetarisc...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'pijnboompitten', 'spinazie', 'g...
# calories                                                            610
# protein                                                              10
# carbohydrates                                                        64
# fat                                                                  35
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        261
# recipe_instruction                                                  NaN
# tags                           ['vegetarisch', ' italiaans', ' bakken']
# appliances                                                           []
# main_ingredient                                          zwarte olijven
# type                                                        ['risotto']
# Name: 804, dtype: object
#
#
# id                                                              1189607
# title                 Boekweitrisotto met rode biet, geitenkaas en p...
# description           ['Risotto', 'ui,', 'knoflook,', 'rode', 'biet,...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'boekweit', 'pijnboompitten', 'v...
# calories                                                            550
# protein                                                              21
# carbohydrates                                                        56
# fat                                                                  24
# saturated_fat                                                         8
# sodium                                                              520
# fiber                                                                12
# cooking_time                                                         35
# rating                                                                4
# review_count                                                          6
# recipe_instruction    Snipper de uien en snijd de knoflook fijn. Sni...
# tags                  ['gezond', ' vegetarisch', ' wat eten we vanda...
# appliances                                                           []
# main_ingredient                                                boekweit
# type                                                        ['risotto']
# Name: 13770, dtype: object
#
#
# id                                                                84418
# title                        Gevulde minipaprika's met stoneleekrisotto
# description           ['lekker', 'recept.', 'vegetarische', 'hoofdge...
# course                                                     hoofdgerecht
# recipe_yield                                                          2
# ingredients           ["cherrypaprika's", 'zure room', 'hazelnoten',...
# calories                                                            480
# protein                                                              13
# carbohydrates                                                        50
# fat                                                                  25
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         45
# rating                                                                3
# review_count                                                         38
# recipe_instruction                                                  NaN
# tags                                           ['vegetarisch', ' oven']
# appliances                               ['kleine lage ovenschaaltjes']
# main_ingredient                                            minipaprikas
# type                                                        ['risotto']
# Name: 15017, dtype: object
#
#
# id                                                              1186438
# title                              Snelle 'risotto' met truffeltapenade
# description           ['In', 'bouillon', 'gekookte', 'rijst', 'champ...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'kokend water', '1 minuut basmat...
# calories                                                            590
# protein                                                              19
# carbohydrates                                                        59
# fat                                                                  29
# saturated_fat                                                        11
# sodium                                                              975
# fiber                                                                 7
# cooking_time                                                         17
# rating                                                                3
# review_count                                                         41
# recipe_instruction    Snijd een stukje van de boven- en onderkant va...
# tags                  ['vegetarisch', ' italiaans', ' wat eten we va...
# appliances                                                           []
# main_ingredient                                                 risotto
# type                                                        ['risotto']
# Name: 4692, dtype: object
#
#
# id                                                               140190
# title                                  Saffraanrisotto met cantharellen
# description           ['lekker', 'italiaans', 'recept.', 'vegetarisc...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['cantharellen of kastanjechampignons', 'kruid...
# calories                                                            880
# protein                                                              23
# carbohydrates                                                        83
# fat                                                                  46
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         40
# rating                                                                3
# review_count                                                         51
# recipe_instruction                                                  NaN
# tags                            ['kerst', ' vegetarisch', ' italiaans']
# appliances                                                           []
# main_ingredient                                                saffraan
# type                                                        ['risotto']
# Name: 4067, dtype: object
#
#
# id                                                               365314
# title                 Rijst met courgette en mozzarella (baby 12-18 ...
# description           ['lekker', 'italiaans', 'recept.', 'vegetarisc...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['mozzarella (kaas)', 'sjalot', 'risottorijst'...
# calories                                                            270
# protein                                                              12
# carbohydrates                                                        31
# fat                                                                  11
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                         19
# recipe_instruction                                                  NaN
# tags                            ['vegetarisch', ' italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                                   rijst
# type                                                        ['risotto']
# Name: 6970, dtype: object
#
#
# id                                                               558348
# title                       Gevulde paprika's met risotto en mozzarella
# description           ["Paprika's", 'gevuld', 'verschillende', 'kaze...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie met knoflookaroma en chilipeper', ...
# calories                                                            430
# protein                                                              17
# carbohydrates                                                        47
# fat                                                                  19
# saturated_fat                                                         8
# sodium                                                              800
# fiber                                                                 4
# cooking_time                                                         45
# rating                                                                3
# review_count                                                        134
# recipe_instruction    Snipper de ui en hak de Italiaanse kruiden fij...
# tags                          ['vegetarisch', ' italiaans', ' grillen']
# appliances                                  ['grilltopper', 'barbecue']
# main_ingredient                                            rode paprika
# type                                                        ['risotto']
# Name: 5010, dtype: object
#
#
# id                                                               133066
# title                                                    Groene risotto
# description           ['Vegetarische', 'risotto', 'rode', 'paprika,'...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'bosuitje', 'rode paprika', 'ger...
# calories                                                            565
# protein                                                              23
# carbohydrates                                                        69
# fat                                                                  19
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                        198
# recipe_instruction    Verhit de olie in een braadpan. Bak de rijst c...
# tags                            ['vegetarisch', ' italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                                 risotto
# type                                                        ['risotto']
# Name: 11807, dtype: object
#
#
# id                                                               416652
# title                           Romige risotto met wortel en gorgonzola
# description           ['lekker', 'italiaans', 'recept.', 'vegetarisc...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'winterpeen', 'risottorijst', 'g...
# calories                                                            835
# protein                                                              18
# carbohydrates                                                        87
# fat                                                                  46
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                         66
# recipe_instruction                                                  NaN
# tags                            ['vegetarisch', ' italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                                 risotto
# type                                                        ['risotto']
# Name: 6673, dtype: object
#
#
# id                                                               561658
# title                                     Tofuspiesjes met bonenrisotto
# description           ['lekker', 'recept.', 'vegetarische', 'hoofdge...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['risottorijst', 'gebroken sperziebonen', 'tui...
# calories                                                            550
# protein                                                              23
# carbohydrates                                                        76
# fat                                                                  17
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                4
# review_count                                                         23
# recipe_instruction                                                  NaN
# tags                  ['vegetarisch', ' wat eten we vandaag', ' gril...
# appliances                                  ['satéstokjes', 'grillpan']
# main_ingredient                                            tofu naturel
# type                                                        ['risotto']
# Name: 209, dtype: object
#
#
# id                                                               312894
# title                   Risotto met portobello en gemengde paddestoelen
# description           ['Vegetarische,', 'Italiaanse', 'risotto', 'pa...
# course                                                     hoofdgerecht
# recipe_yield                                                          2
# ingredients           ['olijfolie', 'verse peterselie', 'walnoten', ...
# calories                                                           1185
# protein                                                              32
# carbohydrates                                                        91
# fat                                                                  71
# saturated_fat                                                        17
# sodium                                                             1160
# fiber                                                                 9
# cooking_time                                                         40
# rating                                                                3
# review_count                                                        158
# recipe_instruction    Veeg de paddenstoelen schoon met keukenpapier ...
# tags                           ['vegetarisch', ' italiaans', ' bakken']
# appliances                                                           []
# main_ingredient                                                 risotto
# type                                                        ['risotto']
# Name: 824, dtype: object
#
#
# id                                                               457344
# title                                  Met risotto gevulde portobello's
# description           ['lekker', 'italiaans', 'recept.', 'vegetarisc...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['bospaddestoelenbouillon', 'boter', 'sherry f...
# calories                                                            375
# protein                                                              12
# carbohydrates                                                        32
# fat                                                                  20
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                        149
# recipe_instruction                                                  NaN
# tags                             ['vegetarisch', ' oven', ' italiaans']
# appliances                                                           []
# main_ingredient                                  portobello champignons
# type                                                        ['risotto']
# Name: 8537, dtype: object
#
#
# id                                                                39540
# title                                Gegrilde oesterzwammen met risotto
# description           ['lekker', 'italiaans', 'recept.', 'vegetarisc...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'witte wijn', 'bosuitjes', 'oude...
# calories                                                            545
# protein                                                              15
# carbohydrates                                                        84
# fat                                                                  16
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         40
# rating                                                                3
# review_count                                                         22
# recipe_instruction                                                  NaN
# tags                          ['vegetarisch', ' italiaans', ' grillen']
# appliances                                             ['keukenpapier']
# main_ingredient                                           oesterzwammen
# type                                                        ['risotto']
# Name: 5784, dtype: object
#
#
# id                                                               613408
# title                               Paddenstoelenrisotto met geitenkaas
# description           ['Vegetarisch', 'Italiaans', 'gerecht', 'risot...
# ...
# rating                                                                3
# review_count                                                          4
# recipe_instruction    Verwarm de oven voor op 180 °C. Halveer de cou...
# tags                      ['oven', ' hollands', ' wat eten we vandaag']
# appliances                                                ['bakpapier']
# main_ingredient                                          maaltijdsalade
# type                                                         ['salade']
# Name: 12913, dtype: object
#
#
# id                                                               358336
# title                          Maaltijdsoep van verse spinazie en kokos
# description           ['Vegetarische', 'maaltijdsoep', 'verse', 'spi...
# course                                                     hoofdgerecht
# recipe_yield                                                          2
# ingredients           ['fijne soepgroente', 'knoflook', 'water', 'ci...
# calories                                                            670
# protein                                                              20
# carbohydrates                                                        71
# fat                                                                  32
# saturated_fat                                                        16
# sodium                                                              750
# fiber                                                                10
# cooking_time                                                         15
# rating                                                                3
# review_count                                                        128
# recipe_instruction    Snipper de ui en pers de knoflook. Verhit de o...
# tags                           ['snel', ' lactosevrij', ' vegetarisch']
# appliances                              ['staafmixer of keukenmachine']
# main_ingredient                                            maaltijdsoep
# type                                                           ['soep']
# Name: 9187, dtype: object
#
#
# id                                                               654590
# title                          Maaltijdsalade met mango en sperziebonen
# description           ['Maaltijdsalade', 'mango,', 'sperziebonen,', ...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'hamburger', 'kropsla', 'gele pa...
# calories                                                            465
# protein                                                              21
# carbohydrates                                                        21
# fat                                                                  33
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        122
# recipe_instruction    Verwijder de steelaanzet en het puntje van de ...
# tags                                            ['hollands', ' bakken']
# appliances                                                           []
# main_ingredient                                          maaltijdsalade
# type                                                         ['salade']
# Name: 4296, dtype: object
#
#
# id                                                              1185883
# title                                     Maaltijdsoep met kip en bonen
# description           ['Maaltijdsoep', 'kidneybonen,', 'bruine', 'bo...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['kraanwater', 'gedroogde dragon', 'bonenmix k...
# calories                                                            295
# protein                                                              27
# carbohydrates                                                        19
# fat                                                                   9
# saturated_fat                                                         3
# sodium                                                             1745
# fiber                                                                16
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         29
# recipe_instruction    Snijd de venkelknollen en kipdijfilet in reepj...
# tags                                    ['snel', ' slank', ' hollands']
# appliances                                                           []
# main_ingredient                                            maaltijdsoep
# type                                                           ['soep']
# Name: 4918, dtype: object
#
#
# id                                                               616284
# title                                                Maaltijdkippensoep
# description           ['Maaltijdsoep', 'thaise', 'groenten,', 'kip,'...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'kraanwater', 'basmatirijst', 'T...
# calories                                                            535
# protein                                                              38
# carbohydrates                                                        63
# fat                                                                  13
# saturated_fat                                                         4
# sodium                                                             1950
# fiber                                                                 7
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        237
# recipe_instruction    Verhit olie in een soeppan en bak de roerbakmi...
# tags                  ['vooraf te maken', ' wat eten we vandaag', ' ...
# appliances                                               ['staafmixer']
# main_ingredient                                     mix voor kip kerrie
# type                                                           ['soep']
# Name: 18481, dtype: object
#
#
# id                                                               473250
# title                                  Franse maaltijdsandwich met paté
# description           ['lekker', 'frans', 'recept.', 'hoofdgerecht',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'Hollandse', 'mosterd', 'kropsla...
# calories                                                            718
# protein                                                              19
# carbohydrates                                                        57
# fat                                                                  46
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                4
# review_count                                                         15
# recipe_instruction                                                  NaN
# tags                                               ['frans', ' bakken']
# appliances                                                           []
# main_ingredient                                        maaltijdsandwich
# type                                                       ['sandwich']
# Name: 7362, dtype: object
#
#
# id                                                               545364
# title                             Maaltijdsoep met lentegroenten en kip
# description           ['lekker', 'hollands', 'recept.', 'hoofdgerech...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'witbrood', 'peen', 'groenteboui...
# calories                                                            470
# protein                                                              33
# carbohydrates                                                        59
# fat                                                                  11
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                         52
# recipe_instruction                                                  NaN
# tags                     ['hollands', ' wat eten we vandaag', ' koken']
# appliances                                                           []
# main_ingredient                                            maaltijdsoep
# type                                                           ['soep']
# Name: 17266, dtype: object
#
#
# id                                                                87590
# title                                            Maaltijdsoep met pesto
# description           ['lekker', 'italiaans', 'recept.', 'vegetarisc...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'pesto rosso', 'Pan Tostado', 'I...
# calories                                                            660
# protein                                                              22
# carbohydrates                                                        72
# fat                                                                  29
# saturated_fat                                                         8
# sodium                                                             1690
# fiber                                                                 6
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         72
# recipe_instruction                                                  NaN
# tags                             ['snel', ' vegetarisch', ' italiaans']
# appliances                                                  ['soeppan']
# main_ingredient                                            maaltijdsoep
# type                                                           ['soep']
# Name: 1223, dtype: object
# id                                                               921614
# title                  Zalm met groene thee, kokosrijst en misogroenten
# description           ['lekker', 'aziatisch', 'recept.', 'hoofdgerec...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['basmatirijst', 'kokend water', 'vloeibare ho...
# calories                                                            715
# protein                                                              36
# carbohydrates                                                        76
# fat                                                                  28
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                4
# review_count                                                         91
# recipe_instruction    Leg de zalmfilets op een bord, trek de zakjes ...
# tags                                   ['snel', ' aziatisch', ' koken']
# appliances                                                           []
# main_ingredient                                                    zalm
# type                                                            ['vis']
# Name: 1855, dtype: object
#
#
# id                                                               861100
# title                            Aziatische vis met noedels en groenten
# description           ['lekker', 'recept.', 'hoofdgerecht', 'bevat',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['fijne eiernoedels', 'sesamzaad', 'vloeibare ...
# calories                                                            430
# protein                                                              36
# carbohydrates                                                        23
# fat                                                                  21
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         50
# recipe_instruction    Vet een kleine, ondiepe ovenschaal of vuurvast...
# tags                                                           ['oven']
# appliances                           ['keukenmachine, lage ovenschaal']
# main_ingredient                                                     vis
# type                                                          ['pasta']
# Name: 13689, dtype: object
#
#
# id                                                              1187629
# title                                 Plaatpizza met spek, ui  spruiten
# description           ['Plaattaart', 'spruiten,', 'crème', 'fraîch...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['crème fraîche', 'Italiaans pizzadeeg met oli...
# calories                                                            595
# protein                                                              21
# carbohydrates                                                        60
# fat                                                                  29
# saturated_fat                                                        14
# sodium                                                             1155
# fiber                                                                 7
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         28
# recipe_instruction    Verwarm de oven voor op 200 °C. Halveer de spr...
# tags                                   ['oven', ' wat eten we vandaag']
# appliances                                                ['bakpapier']
# main_ingredient                                              plaatpizza
# type                                                          ['pizza']
# Name: 10293, dtype: object
