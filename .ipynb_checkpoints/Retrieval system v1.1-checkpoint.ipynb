# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast
from nltk.tokenize import wordpunct_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer

# %% [markdown]
# ## Load in data

# %%
data = pd.read_csv('allerhande_preprocessed.csv', index_col=0)
print(data.head())
# Out:
#         id                                   title  \
# 0   861106            ['vegetarisch', 'bonenstof']
# 1   680104                   ['fris', 'limoenrom']
# 2   683858  ['kalkoenfilet', 'champignonroomsaus']
# 3  1187074     ['andijvie', 'rauw', 'ham', 'prei']
# 4   660152        ['spruit', '-', 'rozijnensalad']
#
#                                          description        course  \
# 0  ['stoofgerecht', 'vegetarisch', 'balletjes', '...  hoofdgerecht
# 1  ['recept', '.', 'nagerecht', 'bevat', 'volgend...     nagerecht
# 2  ['kidsprof', 'winter', 'recept', 'pasta', 'kal...  hoofdgerecht
# 3  ['bijgerecht', 'andijvie', ',', 'prei', ',', '...    bijgerecht
# 4  ['holland', 'recept', '.', 'vegetarisch', 'bij...    bijgerecht
#
#    recipe_yield                                        ingredients  calories  \
# 0           4.0  ['olijfolie', 'tomatenblokjes', 'bruine bon', ...     410.0
# 1           4.0  ['limoen', 'slagrom', 'vloeibare hon', 'grieks...     290.0
# 2           4.0  ['olijfolie', 'gedroogde rozemarijn', 'champig...     585.0
# 3           4.0  ['olijfolie', 'prei', 'knoflok', 'fijngesneden...     175.0
# 4           4.0  ['sladressing bieslok', 'spruitjes', 'bosui', ...     115.0
#
#    protein  carbohydrates   fat  saturated_fat  sodium  fiber  cooking_time  \
# 0     21.0           52.0  10.0            2.0  1040.0   16.0          15.0
# 1      8.0           14.0  22.0            NaN     NaN    NaN          10.0
# 2     41.0           58.0  21.0            0.0     NaN    NaN          25.0
# 3      9.0            7.0  11.0            2.0   475.0    6.0          15.0
# 4      1.0           19.0   4.0            0.0     NaN    NaN          15.0
#
#    rating  review_count                                 recipe_instruction  \
# 0     3.0         483.0                    Verwarm de oven voor op 200 ºC.
# 1     3.0         161.0                                                NaN
# 2     3.0         112.0  Kook de spaghetti volgens de aanwijzingen op d...
# 3     3.0           8.0  Was de preien en snijd ze in ringen. Snijd de ...
# 4     3.0          58.0  Verwijder de buitenste bladeren van de spruite...
#
#                                                tags  \
# 0                ['vegetarisch', ' slank', ' oven']
# 1                                         ['kerst']
# 2  ['italiaans', ' wat eten we vandaag', ' bakken']
# 3       ['glutenvrij', ' lactosevrij', ' hollands']
# 4            ['vegetarisch', ' hollands', ' koken']
#
#                     appliances          type
# 0  ['ovenschaal (20 x 30 cm)']  ['stoofpot']
# 1              ['hoge glazen']     ['fruit']
# 2                           []     ['vlees']
# 3                           []     ['vlees']
# 4                           []    ['salade']

# %%
view_data = pd.read_csv('allerhande_raw.csv', index_col=0)
print(view_data.head())
view_data.drop_duplicates(subset='id', inplace=True)
# Out:
#         id                                title  \
# 0   861106              Vegetarische bonenstoof
# 1   680104                    Frisse limoenroom
# 2   683858  Kalkoenfilet met champignonroomsaus
# 3  1187074       Andijvie met rauwe ham en prei
# 4   660152              Spruiten-rozijnensalade
#
#                                          description        course  \
# 0  Stoofgerecht met vegetarische balletjes, aarda...  hoofdgerecht
# 1  Een lekker recept. Het nagerecht bevat de volg...     nagerecht
# 2  Kidsproof winters recept voor pasta met kalkoe...  hoofdgerecht
# 3  bijgerecht met andijvie, prei, knoflook, tijm ...    bijgerecht
# 4  Een lekker hollands recept. Het vegetarische b...    bijgerecht
#
#   recipe_yield                                        ingredients calories  \
# 0   4 personen  {'olijfolie': '2 el()', 'tomatenblokjes': '800...  410kcal
# 1   4 personen  {'limoenen': ' 2(schoongeboend)', 'slagroom': ...  290kcal
# 2   4 personen  {'olijfolie': '2 el()', 'gedroogde rozemarijn'...  585kcal
# 3   4 personen  {'olijfolie': '2 el()', 'prei': '2 ()', 'knofl...  175kcal
# 4   4 personen  {'sladressing bieslook': '6 el(fles 270 ml)', ...  115kcal
#
#   protein carbohydrates  fat saturated_fat   sodium fiber      cooking_time  \
# 0     21g           52g  10g            2g  1.040mg   16g  15 min. bereiden
# 1      8g           14g  22g           NaN      NaN   NaN  10 min. bereiden
# 2     41g           58g  21g            0g      NaN   NaN  25 min. bereiden
# 3      9g            7g  11g            2g    475mg    6g  15 min. bereiden
# 4      1g           19g   4g            0g      NaN   NaN  15 min. bereiden
#
#    rating  review_count                                 recipe_instruction  \
# 0     3.0         483.0                    Verwarm de oven voor op 200 ºC.
# 1     3.0         161.0                                                NaN
# 2     3.0         112.0  Kook de spaghetti volgens de aanwijzingen op d...
# 3     3.0           8.0  Was de preien en snijd ze in ringen. Snijd de ...
# 4     3.0          58.0  Verwijder de buitenste bladeren van de spruite...
#
#                                               source  \
# 0  Allerhande magazine 2012 nr. 11 - Alles uit de...
# 1  Allerhande magazine 2010 nr. 12 - Kerst nieuw-...
# 2                        Receptkaart 2010 week 50-51
# 3     Allerhande magazine 2016 nr. 05 - Eet de lente
# 4  Allerhande magazine 2010 nr. 09 - Groente volo...
#
#                                              tags                   appliances
# 0                ['vegetarisch', 'slank', 'oven']  ['ovenschaal (20 x 30 cm)']
# 1                                       ['kerst']              ['hoge glazen']
# 2  ['italiaans', 'wat eten we vandaag', 'bakken']                           []
# 3       ['glutenvrij', 'lactosevrij', 'hollands']                           []
# 4            ['vegetarisch', 'hollands', 'koken']                           []

# %% [markdown]
# #### Load in inverted columns and convert to dict

# %%
inverted_ingredients_pd = pd.read_csv('inverted_list_ingredients.csv', header=None, names=['Word', 'Index'])
print(inverted_ingredients_pd.head())
inverted_ingredients_dict = pd.Series(inverted_ingredients_pd.Index.values,index=inverted_ingredients_pd.Word).to_dict()
# Out:
#                                        Word  \
# 0                                datterrini
# 1                  mexicaanse roerbakgroent
# 2                  zachte boter of margarin
# 3  stoomgroenten (broccoli/rode ui/paprika)
# 4                             bruine suiker
#
#                                                Index
# 0                                             [6320]
# 1  [537, 847, 1473, 1544, 2056, 2511, 6391, 6492,...
# 2            [3262, 6202, 6579, 13639, 15010, 16674]
# 3                                            [10181]
# 4  [1442, 2110, 7265, 8615, 9369, 10257, 11532, 1...

# %%
inverted_tags_pd = pd.read_csv('inverted_list_tags.csv', header=None, names=['Word', 'Index'])

# remove row with value NaN
index_nr = []
for i, word in enumerate(inverted_tags_pd['Word']):
    if type(word) is not str:
        index_nr.append(i)
inverted_tags_pd.drop(index_nr, inplace=True)

print(inverted_tags_pd.head())
inverted_tags_dict = pd.Series(inverted_tags_pd.Index.values,index=inverted_tags_pd.Word).to_dict()
# Out:
#                 Word                                              Index
# 1              slank  [0, 45, 67, 135, 172, 221, 260, 344, 369, 386,...
# 2        advertorial                                       [5741, 7705]
# 3   sinterklaasavond  [572, 585, 960, 1132, 1583, 1890, 2594, 3162, ...
# 4        mediterraan  [8, 108, 211, 334, 344, 462, 470, 474, 514, 57...
# 5              turks  [660, 812, 1294, 1425, 1622, 2150, 2170, 2983,...

# %%
inverted_types_pd = pd.read_csv('inverted_list_types.csv', header=None, names=['Word', 'Index'])
print(inverted_types_pd.head())
inverted_types_dict = pd.Series(inverted_types_pd.Index.values,index=inverted_types_pd.Word).to_dict()
# Out:
#         Word                                              Index
# 0       koek  [102, 134, 228, 648, 690, 749, 888, 976, 1005,...
# 1  carpaccio  [11, 19, 23, 34, 778, 1285, 1533, 1644, 1796, ...
# 2         ei  [41, 51, 218, 270, 294, 443, 485, 522, 533, 65...
# 3  chocolade  [371, 2462, 3250, 4764, 5339, 5858, 7796, 9814...
# 4   cocktail  [427, 828, 926, 1251, 1558, 1650, 1818, 2000, ...

# %%
inverted_title_pd = pd.read_csv('inverted_list_title.csv', header=None, names=['Word', 'Index'])
print(inverted_title_pd.head())

# remove row with value NaN
index_nr = []
for i, word in enumerate(inverted_title_pd['Word']):
    if type(word) is not str:
        index_nr.append(i)
inverted_title_pd.drop(index_nr, inplace=True)

inverted_title_dict = pd.Series(inverted_title_pd.Index.values,index=inverted_title_pd.Word).to_dict()
# Out:
#             Word   Index
# 0     peulvrucht  [2591]
# 1   puntasperges  [3194]
# 2    advertorial  [7918]
# 3       pantosti  [6045]
# 4  kaascroissant  [2751]
# [2668]
# 8694

# %% [markdown]
# ## Retrieval system

# %%
def retrieve_inverted_column(word, inverted_column):
    """
    Retrieve the document indices for one query word in one inverted column
    """
    retrieved_docs = []
    for key in inverted_column.keys():
        if word in key:
            retrieved_docs += ast.literal_eval(inverted_column.get(key))
    return list(set(retrieved_docs))

# %% [markdown]
# - tokenize query, remove all tokens that have len = 1, since these are not words
# - for each word in query, create set of documents containing this word
#     - look through each inverted column to retrieve possible documents
# - get the intersection of the document sets of each word to only retrieve documents with all query words
# - print all retrieved documents

# %%
def retrieve(query, inverted_columns, dataset):
    """
    Given a query return the indices of all recipes that meet the requirements.
    """
    tokens = word_tokenize(query)
    words = [item for item in tokens if len(item) > 1]
    
    # lowercase & stemmen
    words = [y.lower() for y in words]
    stemmer = SnowballStemmer("dutch")
    words = [stemmer.stem(y) for y in words]
    
    set_per_word = []
    
    # loop through query words
    for word in words:
        
        # get set of retrieved docs for each word
        retrieved_docs_word = []
        for column in inverted_columns:
            retrieved_docs_word += retrieve_inverted_column(word, column)
        set_per_word.append(set(retrieved_docs_word))
    
    # get intersection of sets for whole query
    retrieved = set_per_word[0]
    for element in set_per_word[1:]:
        retrieved = retrieved.intersection(element)
        
    # print all retrieved recipes
    for index in retrieved:
        print(dataset.iloc[index,:])
        print('\n')
        
    return list(retrieved)

# %% [markdown]
# ## User interface

# %%
from tkinter import *
from PIL import Image, ImageTk

# %%
def click():
    """
    Here the query is gathered, the recipes are retrieved and the titles of the resulting recipes are printed.
    """
    entered_text = textentry.get()
    results.delete(0, END)
    information.delete(0.0, END)
    
    global recipes
    recipes = retrieve(entered_text, [inverted_ingredients_dict, inverted_tags_dict, inverted_types_dict, inverted_title_dict],data)
    for i, element in enumerate(recipes):
        results.insert(END, view_data.iloc[element,1])


def show_descr():
    """
    This function shows the additional information (description and ingredients) of a selected recipe.
    """
    selected_recipe = results.curselection()
    recipe_index = recipes[int(selected_recipe[0])]
    information.delete(0.0, END)
    information.insert(END, "Omschrijving \n", 'big')
    information.insert(END, view_data.iloc[recipe_index,2] + '\n', 'normal')
    information.insert(END, '\nIngrediënten \n', 'big')
    for ingredient in ast.literal_eval(view_data.iloc[recipe_index,5]):
        information.insert(END, ingredient + '\n', 'normal')
    

"""
Below are the general window settings of the UI.
"""
window = Tk()
window.title('Recepten zoeker v.1')
window.configure(background='white')
window.geometry("{}x{}".format(window.winfo_screenwidth(), window.winfo_screenheight()))

image = Image.open("bestek.png")
photo1 = ImageTk.PhotoImage(Image.open("bestek.png"))
Label(window, image=photo1).grid(row=0,column = 0, columnspan = 4, sticky=W+E+N+S)

Label(window, text="Wat wil je eten vanavond?", font='none 24 bold').grid(row=1,column=0,columnspan = 4,sticky=E+W)

### Query box
textentry = Entry(window, width = 75)
textentry.grid(row=3,column=0,columnspan = 4,sticky=W)

Button(window, text='Zoek recepten', width=13, command=click, font='none 18 bold').grid(row=3,column=2,sticky=W)

Label(window, text='Gevonden recepten',font='none 18 bold').grid(row=4,column=0,sticky=E+W)

### Box that shows all retrieved recipes
results = Listbox(window, height = 15, width = 75)
results.grid(row=5,column=0,columnspan=2,sticky=E+W)

### Box that shows additional information about recipe
information = Text(window, width=75, height=15, wrap=WORD)
information.tag_configure('big', font=('none', 14, 'bold'))
information.tag_configure('normal', font=('none', 14))
information.grid(row=5, column=2, columnspan=2, sticky=E+W)

Button(window, text="Klik hier om meer informatie te krijgen over het geselecteerde recept", command=show_descr, font='none 16 bold').grid(row=6, column=0, columnspan=2, sticky=W)

window.mainloop()
# Out:
# id                                                                99488
# title                    ['pittig', 'noedelsoep', 'biefstuk', 'paksoi']
# description           ['chines', 'recept', '.', 'hoofdgerecht', 'bev...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['sereh', 'zout', 'water', 'bosuitj', 'vleesbo...
# calories                                                            345
# protein                                                              26
# carbohydrates                                                        51
# fat                                                                   4
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         40
# rating                                                                3
# review_count                                                         56
# recipe_instruction    Biefstuk in heel dunne plakjes snijden en op k...
# tags                                ['aziatisch', ' chinees', ' koken']
# appliances                                                           []
# type                                                           ['soep']
# Name: 4958, dtype: object
#
#
# id                                                               775764
# title                                          ['stevig', 'kippensoep']
# description           ['maaltijdsoep', 'aardappel', ',', 'winterpen'...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['kraanwater', 'winterpen', 'champignon', 'ver...
# calories                                                            380
# protein                                                              30
# carbohydrates                                                        45
# fat                                                                   6
# saturated_fat                                                         2
# sodium                                                             1345
# fiber                                                                 7
# cooking_time                                                         30
# rating                                                                3
# review_count                                                        122
# recipe_instruction    Schil de aardappelen en snijd ze in blokjes va...
# tags                                                ['slank', ' koken']
# appliances                                                           []
# type                                                           ['soep']
# Name: 7395, dtype: object
#
#
# id                                                                39498
# title                                ['knolselderij', '-', 'crèmesoep']
# description           ['recept', '.', 'vegetarisch', 'voorgerecht', ...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['peper', 'roomboter', 'kruidenbouillontablet'...
# calories                                                            200
# protein                                                               3
# carbohydrates                                                         9
# fat                                                                  16
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         40
# rating                                                                3
# review_count                                                         67
# recipe_instruction    Boven- en onderkant van knolselderij dun eraf ...
# tags                                          ['vegetarisch', ' koken']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 4964, dtype: object
#
#
# id                                                               449096
# title                              ['chines', 'kippensoep', 'spinazie']
# description           ['chines', 'recept', '.', 'hoofdgerecht', 'bev...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['kastanjechampignon', 'kipfilet', 'knoflok', ...
# calories                                                            350
# protein                                                              23
# carbohydrates                                                        32
# fat                                                                  15
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         40
# rating                                                                3
# review_count                                                        175
# recipe_instruction                                                  NaN
# tags                                ['aziatisch', ' chinees', ' koken']
# appliances                                                           []
# type                                                           ['soep']
# Name: 4969, dtype: object
#
#
# id                                                              1189881
# title                      ['prei', '-', 'tuinerwtensoep', 'basilicum']
# description           ['vegetarisch', 'soep', 'van', 'prei', ',', 't...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'gesneden prei', 'water', 'witte...
# calories                                                            280
# protein                                                              12
# carbohydrates                                                        18
# fat                                                                  16
# saturated_fat                                                         6
# sodium                                                             1400
# fiber                                                                 8
# cooking_time                                                         15
# rating                                                                3
# review_count                                                          0
# recipe_instruction    Verhit de olie in een soeppan en fruit de prei...
# tags                                           ['snel', ' vegetarisch']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 9873, dtype: object
#
#
# id                                                               868872
# title                                               ['kruidenroomsaus']
# description           ['recept', '.', 'bijgerecht', 'bevat', 'volgen...
# course                                                       bijgerecht
# recipe_yield                                                          4
# ingredients           ['martini bianco', 'bieslok', 'boter', 'visfon...
# calories                                                            280
# protein                                                               2
# carbohydrates                                                         4
# fat                                                                  27
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         35
# rating                                                                3
# review_count                                                         16
# recipe_instruction    Verhit de boter in een steelpan en bak de groe...
# tags                                                ['kerst', ' koken']
# appliances                                                           []
# type                                                           ['saus']
# Name: 14834, dtype: object
#
#
# id                                                              1187102
# title                                       ['tuinerwtensoep', 'kokos']
# description           ['gebond', 'soep', 'tuinerwt', ',', 'kokos', '...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['koriander', 'bosui', 'kokosolie', 'tuinerwt'...
# calories                                                            280
# protein                                                              11
# carbohydrates                                                        13
# fat                                                                  18
# saturated_fat                                                        14
# sodium                                                              220
# fiber                                                                10
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         33
# recipe_instruction    Breng het water aan de kook. Verwarm ondertuss...
# tags                          ['lactosevrij', ' vegetarisch', ' koken']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 17303, dtype: object
#
#
# id                                                               154382
# title                             ['aardappelsoep', 'gerookt', 'forel']
# description           ['recept', '.', 'voorgerecht', 'bevat', 'volge...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['leffe blond', 'gerookte forelfilet', 'groent...
# calories                                                            265
# protein                                                              10
# carbohydrates                                                        28
# fat                                                                  13
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         35
# rating                                                                3
# review_count                                                         47
# recipe_instruction                                                  NaN
# tags                                                          ['koken']
# appliances                                            ['keukenmachine']
# type                                                           ['soep']
# Name: 20, dtype: object
#
#
# id                                                               869936
# title                        ['soep', 'van', 'tomat', 'rod', 'paprika']
# description           ['soep', 'van', 'geroosterd', 'paprika', "'", ...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'rodewijnazijn', 'olijfolie extr...
# calories                                                            160
# protein                                                               6
# carbohydrates                                                        19
# fat                                                                   6
# saturated_fat                                                         1
# sodium                                                             1905
# fiber                                                                 6
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        498
# recipe_instruction    Snijd de knoflook fijn. Verwarm een grote (soe...
# tags                      ['kerst', ' vegetarisch', ' vooraf te maken']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 14838, dtype: object
#
#
# id                                                               412580
# title                                     ['kippensoep', 'kipbroodjes']
# description           ['holland', 'recept', '.', 'hoofdgerecht', 'be...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['flinterdun gesneden kipfilet', 'kaiserbroodj...
# calories                                                            410
# protein                                                              17
# carbohydrates                                                        31
# fat                                                                  24
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        100
# recipe_instruction                                                  NaN
# tags                                              ['oven', ' hollands']
# appliances                                                           []
# type                                                           ['soep']
# Name: 23, dtype: object
#
#
# id                                                               227640
# title                                     ['gevuld', 'ossenstaartsoep']
# description           ['holland', 'recept', '.', 'hoofdgerecht', 'be...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['ossenstaartsoep', 'bleekselderij', 'sjalot',...
# calories                                                            300
# protein                                                              18
# carbohydrates                                                        33
# fat                                                                  11
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                         34
# recipe_instruction                                                  NaN
# tags                                             ['hollands', ' koken']
# appliances                                                           []
# type                                                           ['soep']
# Name: 4981, dtype: object
#
#
# id                                                              1187691
# title                 ['herfstminestron', 'wit', 'bon', ',', 'spekje...
# description           ['minestron', 'parmezan', 'kas', ',', 'spek', ...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['groentebouillon (van tablet)', 'boerensoepgr...
# calories                                                            NaN
# protein                                                             NaN
# carbohydrates                                                       NaN
# fat                                                                 NaN
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                4
# review_count                                                         17
# recipe_instruction    Verwarm de oven voor op 220 °C en bak het stok...
# tags                                  ['snel', ' budget', ' italiaans']
# appliances                                                  ['soeppan']
# type                                                        ['groente']
# Name: 12378, dtype: object
#
#
# id                                                              1186169
# title                                 ['wokpasta', 'romig', 'kaassaus']
# description           ['spaghettini', 'spekreepjes', ',', 'ui', ',',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['fijne soepgroent', 'kraanwater', 'wokpasta s...
# calories                                                            825
# protein                                                              46
# carbohydrates                                                        64
# fat                                                                  42
# saturated_fat                                                        13
# sodium                                                             1430
# fiber                                                                 8
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         26
# recipe_instruction    Bak de spekreepjes 4 min. op middelhoog vuur i...
# tags                  ['snel', ' wat eten we vandaag', ' roerbakken/...
# appliances                                                           []
# type                                                          ['pasta']
# Name: 14843, dtype: object
#
#
# id                                                               972656
# title                 ['aard', '\xad', 'ap', '\xad', 'pel', '\xad', ...
# description           ['gevuld', 'maaltijdsoep', 'ball', 'van', 'zal...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['kraanwater', 'bieslok', 'maaltijdsoep aardap...
# calories                                                            600
# protein                                                              30
# carbohydrates                                                        64
# fat                                                                  25
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                2
# review_count                                                         56
# recipe_instruction    Was de prei en snijd deze in ringen. Snijd de ...
# tags                  ['zonder vlees', ' hollands', ' wat eten we va...
# appliances                              ['staafmixer of keukenmachine']
# type                                                           ['soep']
# Name: 9887, dtype: object
#
#
# id                                                               234740
# title                 ['pittig', 'tomatensoep', 'gember', '-', 'pepe...
# description           ['recept', '.', 'vegetarisch', 'voorgerecht', ...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['tomatenpuree', 'versgemalen zwarte peper', '...
# calories                                                            195
# protein                                                               2
# carbohydrates                                                         5
# fat                                                                  19
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                         50
# recipe_instruction                                                  NaN
# tags                                          ['vegetarisch', ' koken']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 4980, dtype: object
#
#
# id                                                              1185541
# title                                       ['spinaziesoep', 'ravioli']
# description           ['romig', 'soep', 'van', 'spinazie', ',', 'pas...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'volkoren ravioli ricotta/spinaz...
# calories                                                            440
# protein                                                              20
# carbohydrates                                                        36
# fat                                                                  22
# saturated_fat                                                        11
# sodium                                                             1690
# fiber                                                                 9
# cooking_time                                                         15
# rating                                                                3
# review_count                                                        119
# recipe_instruction    Schil de aardappelen en snijd in blokjes van 1...
# tags                     ['snel', ' italiaans', ' wat eten we vandaag']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 19779, dtype: object
#
#
# id                                                               712898
# title                                               ['borrelballetjes']
# description           ['recept', '.', 'borrelhapj', 'bevat', 'volgen...
# course                                                      borrelhapje
# recipe_yield                                                          6
# ingredients                        ['olijfolie', 'verse soepballetjes']
# calories                                                            225
# protein                                                              14
# carbohydrates                                                       NaN
# fat                                                                  19
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                          5
# rating                                                                2
# review_count                                                         58
# recipe_instruction    Verhit de olie in een hapjespan en strooi de s...
# tags                                    ['sinterklaasavond', ' bakken']
# appliances                                                           []
# type                                                           ['soep']
# Name: 4992, dtype: object
#
#
# id                                                               694620
# title                                ['meloensoep', 'citroensorbetijs']
# description           ['recept', '.', 'nagerecht', 'bevat', 'volgend...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['framboz', 'citroensorbetijs', 'poedersuiker'...
# calories                                                            185
# protein                                                               2
# carbohydrates                                                        39
# fat                                                                   0
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         21
# recipe_instruction                                                  NaN
# tags                                                               ['']
# appliances                                            ['keukenmachine']
# type                                                           ['soep']
# Name: 4993, dtype: object
#
#
# id                                                               429212
# title                                 ['romig', 'groen', 'aspergesoep']
# description           ['groen', 'aspergesoep', 'tuinerwt', ',', 'ome...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['kraanwater', 'bieslok', 'stokbrod', 'olijfol...
# calories                                                            535
# protein                                                              17
# carbohydrates                                                        65
# fat                                                                  23
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                         64
# recipe_instruction    Breek de onderkant van de asperges en snijd de...
# tags                             ['vegetarisch', ' hollands', ' koken']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 2507, dtype: object
#
#
# id                                                               759618
# title                                        ['kruidig', 'pompoensoep']
# description           ['kruidig', 'pompoensoep', 'paprika', ',', 'bo...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'bosuitj', 'rode paprika', 'chil...
# calories                                                            215
# protein                                                               5
# carbohydrates                                                        23
# fat                                                                  12
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        372
# recipe_instruction    Halveer de pompoen en schep de zaden en de dra...
# tags                                          ['vegetarisch', ' koken']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 17331, dtype: object
#
#
# id                                                               845632
# title                              ['venkelsoep', 'kipgehaktballetjes']
# description           ['recept', '.', 'hoofdgerecht', 'bevat', 'volg...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['kippenbouillontablet', 'boter', 'bieslok', '...
# calories                                                            565
# protein                                                              22
# carbohydrates                                                        42
# fat                                                                  32
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                4
# review_count                                                         91
# recipe_instruction    Verwarm de oven voor op 220 °C. Snijd de venke...
# tags                                               ['budget', ' koken']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 50, dtype: object
#
#
# id                                                               517050
# title                                              ['eipotj', 'rucola']
# description           ['koolhydraatarm', 'italiaan', 'recept', 'eipo...
# course                                                          ontbijt
# recipe_yield                                                          4
# ingredients           ['slagrom', 'rucola', 'kaasflakes', 'ei', 'soe...
# calories                                                            180
# protein                                                              10
# carbohydrates                                                         7
# fat                                                                  12
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         10
# rating                                                                3
# review_count                                                         27
# recipe_instruction    Verwarm de oven voor op 200 °C. Verdeel de sla...
# tags                                 ['kerst', ' vegetarisch', ' oven']
# appliances            ['eenpersoonsovenschaaltje', 'braadslee of ove...
# type                                                             ['ei']
# Name: 52, dtype: object
#
#
# id                                                              1188280
# title                                                     ['sushisoep']
# description           ['soep', 'van', 'sushirijst', ',', 'kokosmelk'...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['geroosterd zwart sesamzad', 'water', 'kokosm...
# calories                                                            561
# protein                                                              18
# carbohydrates                                                        30
# fat                                                                  40
# saturated_fat                                                        19
# sodium                                                             1160
# fiber                                                                 3
# cooking_time                                                         30
# rating                                                                3
# review_count                                                          9
# recipe_instruction    Doe de sushirijst in een zeef en spoel af onde...
# tags                    ['aziatisch', ' wat eten we vandaag', ' koken']
# appliances                                                           []
# type                                                           ['soep']
# Name: 19793, dtype: object
#
#
# id                                                               424756
# title                                                   ['tomatensoep']
# description           ['tomatensoep', 'basilicum', 'bladerdeg', 'zee...
# course                                                     hoofdgerecht
# recipe_yield                                                          2
# ingredients           ['tomatensoep basilicum', 'olijfolie', 'grof z...
# calories                                                            355
# protein                                                               4
# carbohydrates                                                        27
# fat                                                                  26
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                          5
# rating                                                                2
# review_count                                                        164
# recipe_instruction                                                  NaN
# tags                                           ['vegetarisch', ' oven']
# appliances                    ['ovenvaste soepkommen, inhoud ca. 3 dl']
# type                                                           ['soep']
# Name: 7442, dtype: object
#
#
# id                                                               465558
# title                                ['aardappel', '-', 'knoflooksoep']
# description           ['recept', '.', 'vegetarisch', 'voorgerecht', ...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'kruimige aardappel', 'knoflok',...
# calories                                                            140
# protein                                                               6
# carbohydrates                                                        13
# fat                                                                   7
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        117
# recipe_instruction                                                  NaN
# tags                               ['vegetarisch', ' budget', ' koken']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 7441, dtype: object
#
#
# id                                                               961572
# title                                                     ['minestron']
# description           ['stevig', 'italiaan', 'maaltijdgroentesoep', ...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['cannellinibon', 'kraanwater', 'boter', 'vers...
# calories                                                            405
# protein                                                              18
# carbohydrates                                                        41
# fat                                                                  17
# saturated_fat                                                         6
# sodium                                                             1155
# fiber                                                                 9
# cooking_time                                                         30
# rating                                                                4
# review_count                                                         91
# recipe_instruction         Snipper de ui en snijd het spek in blokjes.
# tags                        ['vooraf te maken', ' italiaans', ' koken']
# appliances                                                           []
# type                                                           ['soep']
# Name: 2518, dtype: object
#
#
# id                                                               719526
# title                      ['gevuld', 'noedelsoep', 'prei', '-', 'kip']
# description           ['recept', '.', 'hoofdgerecht', 'bevat', 'volg...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['gerookte kipfilet', 'eiernoedel', 'prei', 't...
# calories                                                            540
# protein                                                              39
# carbohydrates                                                        60
# fat                                                                  16
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                        161
# recipe_instruction    Breng de bouillon in een pan aan de kook en vo...
# tags                         ['snel', ' wat eten we vandaag', ' koken']
# appliances                                             ['broodrooster']
# type                                                           ['soep']
# Name: 59, dtype: object
#
#
# id                                                               453410
# title                 ['bloeder', 'pompoensoep', 'krokant', 'spookho...
# description           ['halloweensoep', 'pompoen', ',', 'ui', 'knofl...
# course                                                       bijgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'tomatensap', 'knoflok', 'water'...
# calories                                                            265
# protein                                                               5
# carbohydrates                                                        35
# fat                                                                  10
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         50
# rating                                                                3
# review_count                                                         91
# recipe_instruction    Halveer de pompoen en verwijder de zaden en de...
# tags                            ['vegetarisch', ' halloween', ' koken']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 9932, dtype: object
#
#
# id                                                              1187025
# title                            ['fusilli', 'paddenstoelensaus', 'ei']
# description           ['pasta', 'paddenstoel', ',', 'ui', 'ver', 'pa...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'fusilli', 'knoflok', 'paddensto...
# calories                                                            630
# protein                                                              21
# carbohydrates                                                        71
# fat                                                                  28
# saturated_fat                                                        12
# sodium                                                              760
# fiber                                                                 5
# cooking_time                                                         15
# rating                                                                2
# review_count                                                         51
# recipe_instruction    Kook de pasta volgens de aanwijzingen op de ve...
# tags                        ['snel', ' zonder vlees/vis', ' italiaans']
# appliances                                                           []
# type                                                          ['pasta']
# Name: 2541, dtype: object
#
#
# id                                                              1187949
# title                            ['romig', 'kippensoep', 'paddenstoel']
# description           ['romig', 'soep', 'ui', ',', 'knoflok', ',', '...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['mix voor kippensoep', 'kookrom', 'selderij',...
# calories                                                            370
# protein                                                              20
# carbohydrates                                                        21
# fat                                                                  22
# saturated_fat                                                        10
# sodium                                                             1725
# fiber                                                                 3
# cooking_time                                                         15
# rating                                                                4
# review_count                                                         17
# recipe_instruction                                                  NaN
# tags                                            ['wat eten we vandaag']
# appliances                                                           []
# type                                                           ['soep']
# Name: 80, dtype: object
#
#
# id                                                               406166
# title                             ['romig', 'bloemkoolsoep', 'amandel']
# description           ['recept', '.', 'vegetarisch', 'voorgerecht', ...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'crème fraîch', 'panklare bloemk...
# calories                                                            215
# protein                                                               4
# carbohydrates                                                         7
# fat                                                                  19
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                        129
# recipe_instruction                                                  NaN
# tags                                          ['vegetarisch', ' koken']
# appliances                              ['staafmixer of keukenmachine']
# type                                                           ['soep']
# Name: 5034, dtype: object
#
#
# id                                                               179256
# title                                           ['zwitser', 'kaassoep']
# description           ['recept', '.', 'vegetarisch', 'voorgerecht', ...
# course                                                      voorgerecht
# recipe_yield                                                          8
# ingredients           ['bloem', 'gedroogde dragon', 'boter', 'rucola...
# calories                                                            300
# protein                                                              13
# carbohydrates                                                         9
# fat                                                                  22
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                         27
# recipe_instruction                                                  NaN
# tags                                ['vegetarisch', ' pasen', ' koken']
# appliances                                                           []
# type                                                           ['soep']
# Name: 19829, dtype: object
#
#
# id                                                               375650
# title                     ['wit', '-', 'bonensoep', 'basilicumtapenad']
# description           ['italiaan', 'recept', '.', 'vegetarisch', 'ho...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'witte bon', 'italiaanse roerbak...
# calories                                                            630
# protein                                                              21
# carbohydrates                                                        68
# fat                                                                  31
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# ...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['rodewijnazijn', 'knoflok', 'trostomat', 'ext...
# calories                                                            535
# protein                                                              13
# carbohydrates                                                        55
# fat                                                                  28
# saturated_fat                                                         4
# sodium                                                              540
# fiber                                                                 8
# cooking_time                                                         30
# rating                                                                3
# review_count                                                         57
# recipe_instruction    Pel en pers de knoflook boven een kommetje. Sc...
# tags                         ['lactosevrij', ' vegetarisch', ' spaans']
# appliances                                                           []
# type                                                           ['soep']
# Name: 10448, dtype: object
#
#
# id                                                               358336
# title                 ['maaltijdsoep', 'van', 'ver', 'spinazie', 'ko...
# description           ['vegetarisch', 'maaltijdsoep', 'ver', 'spinaz...
# course                                                     hoofdgerecht
# recipe_yield                                                          2
# ingredients           ['fijne soepgroent', 'knoflok', 'water', 'ciab...
# calories                                                            670
# protein                                                              20
# carbohydrates                                                        71
# fat                                                                  32
# saturated_fat                                                        16
# sodium                                                              750
# fiber                                                                10
# cooking_time                                                         15
# rating                                                                3
# review_count                                                        128
# recipe_instruction    Snipper de ui en pers de knoflook. Verhit de o...
# tags                           ['snel', ' lactosevrij', ' vegetarisch']
# appliances                              ['staafmixer of keukenmachine']
# type                                                           ['soep']
# Name: 9187, dtype: object
#
#
# id                                                              1185077
# title                                    ['pompoensoep', 'uit', 'oven']
# description           ['pompoensoep', 'uit', 'oven', 'bospen', ',', ...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['kraanwater', 'flespompoen', 'hazelnot', 'kno...
# calories                                                            640
# protein                                                               8
# carbohydrates                                                        22
# fat                                                                  56
# saturated_fat                                                        24
# sodium                                                             1045
# fiber                                                                 8
# cooking_time                                                         30
# rating                                                                3
# review_count                                                        291
# recipe_instruction    Verwarm de oven voor op 220 °C. Halveer de pom...
# tags                                           ['vegetarisch', ' oven']
# appliances                                     ['bakpapier', 'blender']
# type                                                           ['soep']
# Name: 6725, dtype: object
#
#
# id                                                               882624
# title                                                   ['groentesoep']
# description           ['basisrecept', 'groentesoep', 'winterpen', ',...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['winterpen', 'kraanwater', 'bleekselderij', '...
# calories                                                             70
# protein                                                               3
# carbohydrates                                                         9
# fat                                                                   1
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                2
# review_count                                                        162
# recipe_instruction    Snijd de uiteinden van de winterpeen ruim af e...
# tags                             ['vegetarisch', ' hollands', ' koken']
# appliances                                                           []
# type                                                           ['soep']
# Name: 17247, dtype: object
#
#
# id                                                                71024
# title                       ['knoflooksoep', 'geroosterd', 'aardappel']
# description           ['recept', '.', 'vegetarisch', 'voorgerecht', ...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'roomkaas met knoflok', 'maggikr...
# calories                                                            345
# protein                                                               9
# carbohydrates                                                        11
# fat                                                                  29
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         60
# rating                                                                3
# review_count                                                         41
# recipe_instruction                                                  NaN
# tags                                          ['vegetarisch', ' koken']
# appliances                               ['keukenpapier', 'staafmixer']
# type                                                           ['soep']
# Name: 7364, dtype: object
#
#
# id                                                                99462
# title                                             ['kokossoep', 'tofu']
# description           ['recept', '.', 'vegetarisch', 'voorgerecht', ...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['sereh', 'bosuitjes', 'verse (kaneel)basilicu...
# calories                                                            310
# protein                                                              12
# carbohydrates                                                         9
# fat                                                                  25
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         60
# rating                                                                3
# review_count                                                         39
# recipe_instruction                                                  NaN
# tags                                          ['vegetarisch', ' koken']
# appliances                                      ['wok', 'keukenpapier']
# type                                                           ['soep']
# Name: 9215, dtype: object
#
#
# id                                                               640446
# title                                        ['romig', 'courgettesoep']
# description           ['soep', 'van', 'courgettes', 'rom', ',', 'pro...
# course                                                      voorgerecht
# recipe_yield                                                          6
# ingredients           ['olijfolie', 'gedroogde provençaalse kruid', ...
# calories                                                            370
# protein                                                               4
# carbohydrates                                                         9
# fat                                                                  35
# saturated_fat                                                        11
# sodium                                                              670
# fiber                                                                 1
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        988
# recipe_instruction    Snipper de ui en snijd de courgette in blokjes...
# tags                   ['vegetarisch', ' vooraf te maken', ' hollands']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 19118, dtype: object
#
#
# id                                                              1189680
# title                   ['tuinerwtensoep', 'geroosterd', 'cherrytomat']
# description           ['soep', 'gemaakt', 'van', 'tuinerwt', 'groent...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['gezouten roomboter', 'robuust stokbrood brui...
# calories                                                            445
# protein                                                              11
# carbohydrates                                                        46
# fat                                                                  22
# saturated_fat                                                        11
# sodium                                                              880
# fiber                                                                10
# cooking_time                                                         20
# rating                                                                5
# review_count                                                          2
# recipe_instruction    Verwarm de oven voor op 200 °C. Snijd het stok...
# tags                      ['kerst', ' vegetarisch', ' vooraf te maken']
# appliances                                     ['bakpapier', 'blender']
# type                                                           ['soep']
# Name: 14810, dtype: object
#
#
# id                                                               334888
# title                                          ['raapstelensoep', 'ei']
# description           ['vegatarisch', 'soep', 'van', 'kruidenbouillo...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['raapstel', 'boter', 'tuinkruidenbouillon', '...
# calories                                                            135
# protein                                                               6
# carbohydrates                                                         9
# fat                                                                   9
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                         60
# recipe_instruction    Kook de eieren in 6-7 min. net hard. Maak de b...
# tags                             ['vegetarisch', ' hollands', ' koken']
# appliances                              ['staafmixer of keukenmachine']
# type                                                           ['soep']
# Name: 12962, dtype: object
#
#
# id                                                               472484
# title                            ['koud', 'aardappel', '-', 'roomsoep']
# description           ['fran', 'recept', '.', 'vegetarisch', 'voorge...
# course                                                      voorgerecht
# recipe_yield                                                          8
# ingredients           ['kruimige aardappel', 'boter', 'sjalot', 'crè...
# calories                                                            100
# protein                                                               1
# carbohydrates                                                         5
# fat                                                                   9
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         40
# rating                                                                3
# review_count                                                         39
# recipe_instruction                                                  NaN
# tags                                ['vegetarisch', ' frans', ' koken']
# appliances                                               ['staafmixer']
# type                                                           ['soep']
# Name: 15443, dtype: object
#
#
# id                                                                87590
# title                                         ['maaltijdsoep', 'pesto']
# description           ['italiaan', 'recept', '.', 'vegetarisch', 'ho...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'pesto rosso', 'pan tostado', 'i...
# calories                                                            660
# protein                                                              22
# carbohydrates                                                        72
# fat                                                                  29
# saturated_fat                                                         8
# sodium                                                             1690
# fiber                                                                 6
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         72
# recipe_instruction                                                  NaN
# tags                             ['snel', ' vegetarisch', ' italiaans']
# appliances                                                  ['soeppan']
# type                                                           ['soep']
# Name: 1223, dtype: object
