# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast
from nltk.tokenize import wordpunct_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer

# %% [markdown]
# #### Load in data

# %%
data = pd.read_csv('allerhande_preprocessed.csv', index_col=0)
print(data.head())
# Out:
#         id                                   title  \
# 0   861106            ['vegetarisch', 'bonenstof']
# 1   680104                   ['fris', 'limoenrom']
# 2   683858  ['kalkoenfilet', 'champignonroomsaus']
# 3  1187074     ['andijvie', 'rauw', 'ham', 'prei']
# 4   660152        ['spruit', '-', 'rozijnensalad']
#
#                                          description        course  \
# 0  ['stoofgerecht', 'vegetarisch', 'balletjes', '...  hoofdgerecht
# 1  ['recept', '.', 'nagerecht', 'bevat', 'volgend...     nagerecht
# 2  ['kidsprof', 'winter', 'recept', 'pasta', 'kal...  hoofdgerecht
# 3  ['bijgerecht', 'andijvie', ',', 'prei', ',', '...    bijgerecht
# 4  ['holland', 'recept', '.', 'vegetarisch', 'bij...    bijgerecht
#
#    recipe_yield                                        ingredients  calories  \
# 0           4.0  ['olijfolie', 'tomatenblokjes', 'bruine bon', ...     410.0
# 1           4.0  ['limoen', 'slagrom', 'vloeibare hon', 'grieks...     290.0
# 2           4.0  ['olijfolie', 'gedroogde rozemarijn', 'champig...     585.0
# 3           4.0  ['olijfolie', 'prei', 'knoflok', 'fijngesneden...     175.0
# 4           4.0  ['sladressing bieslok', 'spruitjes', 'bosui', ...     115.0
#
#    protein  carbohydrates   fat  ...  sodium  fiber  cooking_time  rating  \
# 0     21.0           52.0  10.0  ...  1040.0   16.0          15.0     3.0
# 1      8.0           14.0  22.0  ...     NaN    NaN          10.0     3.0
# 2     41.0           58.0  21.0  ...     NaN    NaN          25.0     3.0
# 3      9.0            7.0  11.0  ...   475.0    6.0          15.0     3.0
# 4      1.0           19.0   4.0  ...     NaN    NaN          15.0     3.0
#
#    review_count                                 recipe_instruction  \
# 0         483.0                    Verwarm de oven voor op 200 ºC.
# 1         161.0                                                NaN
# 2         112.0  Kook de spaghetti volgens de aanwijzingen op d...
# 3           8.0  Was de preien en snijd ze in ringen. Snijd de ...
# 4          58.0  Verwijder de buitenste bladeren van de spruite...
#
#                                                tags  \
# 0                ['vegetarisch', ' slank', ' oven']
# 1                                         ['kerst']
# 2  ['italiaans', ' wat eten we vandaag', ' bakken']
# 3       ['glutenvrij', ' lactosevrij', ' hollands']
# 4            ['vegetarisch', ' hollands', ' koken']
#
#                     appliances        main_ingredient                type
# 0  ['ovenschaal (20 x 30 cm)']           bruine bonen        ['stoofpot']
# 1              ['hoge glazen']             limoenroom  ['Type not found']
# 2                           []           kalkoenfilet           ['vlees']
# 3                           []  fijngesneden andijvie           ['vlees']
# 4                           []               rozijnen          ['salade']
#
# [5 rows x 21 columns]

# %%
view_data = pd.read_csv('allerhande_raw.csv', index_col=0)
print(view_data.head())
view_data.drop_duplicates(subset='id', inplace=True)
# Out:
#         id                                title  \
# 0   861106              Vegetarische bonenstoof
# 1   680104                    Frisse limoenroom
# 2   683858  Kalkoenfilet met champignonroomsaus
# 3  1187074       Andijvie met rauwe ham en prei
# 4   660152              Spruiten-rozijnensalade
#
#                                          description        course  \
# 0  Stoofgerecht met vegetarische balletjes, aarda...  hoofdgerecht
# 1  Een lekker recept. Het nagerecht bevat de volg...     nagerecht
# 2  Kidsproof winters recept voor pasta met kalkoe...  hoofdgerecht
# 3  bijgerecht met andijvie, prei, knoflook, tijm ...    bijgerecht
# 4  Een lekker hollands recept. Het vegetarische b...    bijgerecht
#
#   recipe_yield                                        ingredients calories  \
# 0   4 personen  {'olijfolie': '2 el()', 'tomatenblokjes': '800...  410kcal
# 1   4 personen  {'limoenen': ' 2(schoongeboend)', 'slagroom': ...  290kcal
# 2   4 personen  {'olijfolie': '2 el()', 'gedroogde rozemarijn'...  585kcal
# 3   4 personen  {'olijfolie': '2 el()', 'prei': '2 ()', 'knofl...  175kcal
# 4   4 personen  {'sladressing bieslook': '6 el(fles 270 ml)', ...  115kcal
#
#   protein carbohydrates  fat saturated_fat   sodium fiber      cooking_time  \
# 0     21g           52g  10g            2g  1.040mg   16g  15 min. bereiden
# 1      8g           14g  22g           NaN      NaN   NaN  10 min. bereiden
# 2     41g           58g  21g            0g      NaN   NaN  25 min. bereiden
# 3      9g            7g  11g            2g    475mg    6g  15 min. bereiden
# 4      1g           19g   4g            0g      NaN   NaN  15 min. bereiden
#
#    rating  review_count                                 recipe_instruction  \
# 0     3.0         483.0                    Verwarm de oven voor op 200 ºC.
# 1     3.0         161.0                                                NaN
# 2     3.0         112.0  Kook de spaghetti volgens de aanwijzingen op d...
# 3     3.0           8.0  Was de preien en snijd ze in ringen. Snijd de ...
# 4     3.0          58.0  Verwijder de buitenste bladeren van de spruite...
#
#                                               source  \
# 0  Allerhande magazine 2012 nr. 11 - Alles uit de...
# 1  Allerhande magazine 2010 nr. 12 - Kerst nieuw-...
# 2                        Receptkaart 2010 week 50-51
# 3     Allerhande magazine 2016 nr. 05 - Eet de lente
# 4  Allerhande magazine 2010 nr. 09 - Groente volo...
#
#                                              tags                   appliances
# 0                ['vegetarisch', 'slank', 'oven']  ['ovenschaal (20 x 30 cm)']
# 1                                       ['kerst']              ['hoge glazen']
# 2  ['italiaans', 'wat eten we vandaag', 'bakken']                           []
# 3       ['glutenvrij', 'lactosevrij', 'hollands']                           []
# 4            ['vegetarisch', 'hollands', 'koken']                           []

# %% [markdown]
# #### Load in inverted columns and convert to dict

# %%
inverted_ingredients_pd = pd.read_csv('inverted_list_ingredients.csv', header=None, names=['Word', 'Index'])
print(inverted_ingredients_pd.head())
inverted_ingredients_dict = pd.Series(inverted_ingredients_pd.Index.values,index=inverted_ingredients_pd.Word).to_dict()
# Out:
#                                Word                     Index
# 0                chinese-groentemix  [967, 8407, 8856, 10451]
# 1  paddenstoelenmix paprika bieslok                   [13788]
# 2                           bananas                    [7345]
# 3              aziatische wokgroent             [7595, 15247]
# 4              kruidenmix voor nasi                   [11139]

# %%
inverted_tags_pd = pd.read_csv('inverted_list_tags.csv', header=None, names=['Word', 'Index'])
# remove row with value NaN
index_nr = []
for i, word in enumerate(inverted_tags_pd['Word']):
    if type(word) is not str:
        index_nr.append(i)
inverted_tags_pd.drop(index_nr, inplace=True)
print(inverted_tags_pd.head())
inverted_tags_dict = pd.Series(inverted_tags_pd.Index.values,index=inverted_tags_pd.Word).to_dict()
# Out:
#                Word                                              Index
# 1  zonder vlees/vis  [14, 52, 59, 74, 174, 185, 245, 296, 311, 385,...
# 2         caribisch                                 [649, 4952, 10112]
# 3             frans  [44, 93, 107, 233, 246, 312, 325, 413, 430, 44...
# 4             pasen  [109, 634, 801, 1045, 1293, 1305, 1559, 1574, ...
# 5         traktatie  [2848, 4303, 6495, 7928, 8161, 9488, 14460, 16...

# %%
inverted_types_pd = pd.read_csv('inverted_list_types.csv', header=None, names=['Word', 'Index'])
print(inverted_types_pd.head())
inverted_types_dict = pd.Series(inverted_types_pd.Index.values,index=inverted_types_pd.Word).to_dict()
# Out:
#              Word                                              Index
# 0         hutspot  [766, 1082, 2267, 2794, 3092, 4189, 4266, 4617...
# 1      pannenkoek  [204, 248, 368, 414, 497, 572, 586, 786, 917, ...
# 2           fruit  [282, 877, 2094, 5986, 6117, 6609, 8763, 12188...
# 3  Type not found  [1, 17, 41, 51, 98, 101, 104, 121, 124, 126, 1...
# 4        stoofpot  [0, 62, 63, 167, 183, 314, 325, 327, 389, 537,...

# %%
inverted_title_pd = pd.read_csv('inverted_list_title.csv', header=None, names=['Word', 'Index'])
print(inverted_title_pd.head())
index_nr = []
for i, word in enumerate(inverted_title_pd['Word']):
    if type(word) is not str:
        index_nr.append(i)
print(index_nr)
print(len(inverted_title_pd['Word']))
# print(index_nr)
inverted_title_pd.drop(index_nr, inplace=True)
inverted_title_dict = pd.Series(inverted_title_pd.Index.values,index=inverted_title_pd.Word).to_dict()
# Out:
#              Word    Index
# 0        taglioni   [7690]
# 1         bananas  [16662]
# 2     koffiewafel    [618]
# 3  rodekooltaartj   [6256]
# 4        crawfish   [8587]
# [5065]
# 8691

# %% [markdown]
# #### First for only one word in only one inverted column

# %%
# word = str, inverted_column = dict, retrieved_docs = list
def retrieve_inverted_column(word, inverted_column):
    retrieved_docs = []
    for key in inverted_column.keys():
        if word in key:
            retrieved_docs += ast.literal_eval(inverted_column.get(key))
    return list(set(retrieved_docs))

# %% [markdown]
# ## Retrieval system
# - tokenize query, remove all tokens that have len = 1, since these are not words
# - for each word in query, create set of documents containing this word
#     - look through each inverted column to retrieve possible documents
# - get the intersection of the document sets of each word to only retrieve documents with all query words
# - print all retrieved documents

# %%
# query = str, inverted_column = list of dicts?
def retrieve(query, inverted_columns, dataset):
    tokens = word_tokenize(query)
    words = [item for item in tokens if len(item) > 1]
    
    # lowercase & stemmen
    words = [y.lower() for y in words]
    stemmer = SnowballStemmer("dutch")
    words = [stemmer.stem(y) for y in words]
    
    set_per_word = []
    
    # loop through query words
    for word in words:
        
        # get set of retrieved docs for each word
        retrieved_docs_word = []
        for column in inverted_columns:
            retrieved_docs_word += retrieve_inverted_column(word, column)
        set_per_word.append(set(retrieved_docs_word))
    
    # get intersection of sets for whole query
    retrieved = set_per_word[0]
    for element in set_per_word[1:]:
        retrieved = retrieved.intersection(element)
        
    # print all retrieved recipes
    for index in retrieved:
        print(dataset.iloc[index,:])
        print('\n')
        
    return list(retrieved)

# %%
test1 = retrieve("ijskoffie", [inverted_ingredients_dict, inverted_tags_dict, inverted_types_dict, inverted_title_dict],data)
print(test1)
print(data.iloc[test1[0],1])
print(view_data.iloc[test1[0],1])
# Out:
# id                                                               549844
# title                                        ['ijskoffie', 'chocorasp']
# description           ['recept', '.', 'vegetarisch', 'nagerecht', 'b...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients                   ['sterke koffie', 'pure chocolad', 'ijs']
# calories                                                            105
# protein                                                               2
# carbohydrates                                                        12
# fat                                                                   6
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                          5
# rating                                                                3
# review_count                                                         92
# recipe_instruction                                                  NaN
# tags                                                    ['vegetarisch']
# appliances                                            ['4 hoge glazen']
# main_ingredient                                           sterke koffie
# type                                                         ['koffie']
# Name: 3714, dtype: object
#
#
# id                                                               208532
# title                                      ['ijskoffie', 'advocaatrom']
# description           ['recept', '.', 'vegetarisch', 'nagerecht', 'b...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['vanillesuiker', 'scharreladvocat', 'cafe au ...
# calories                                                            325
# protein                                                               5
# carbohydrates                                                        32
# fat                                                                  19
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         10
# rating                                                                3
# review_count                                                         16
# recipe_instruction                                                  NaN
# tags                                                    ['vegetarisch']
# appliances                                                           []
# main_ingredient                                               ijskoffie
# type                                                 ['Type not found']
# Name: 3926, dtype: object
#
#
# id                                                               140226
# title                                                     ['ijskoffie']
# description           ['recept', '.', 'vegetarisch', 'nagerecht', 'b...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients               ['vanilleroomijs', 'likeur', 'hete espresso']
# calories                                                            NaN
# protein                                                             NaN
# carbohydrates                                                       NaN
# fat                                                                 NaN
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                          5
# rating                                                                2
# review_count                                                         18
# recipe_instruction                                                  NaN
# tags                                          ['kerst', ' vegetarisch']
# appliances                                                           []
# main_ingredient                                               ijskoffie
# type                                                         ['koffie']
# Name: 400, dtype: object
#
#
# id                                                               468752
# title                                    ['ijskoffie', 'lobbig', 'rom']
# description           ['recept', '.', 'vegetarisch', 'nagerecht', 'b...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['suiker', 'slagrom', 'ijsklontjes', 'koffie',...
# calories                                                            274
# protein                                                               2
# carbohydrates                                                        17
# fat                                                                  22
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         10
# rating                                                                3
# review_count                                                         32
# recipe_instruction                                                  NaN
# tags                                                    ['vegetarisch']
# appliances                                                           []
# main_ingredient                                                  koffie
# type                                                 ['Type not found']
# Name: 13214, dtype: object
#
#
# id                                                               517076
# title                                                     ['ijskoffie']
# description           ['recept', '.', 'vegetarisch', 'nagerecht', 'b...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['kaneelpoeder', 'chocoladestick', 'witte bast...
# calories                                                              0
# protein                                                               0
# carbohydrates                                                         0
# fat                                                                   0
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         84
# recipe_instruction                                                  NaN
# tags                                ['kerst', ' vegetarisch', ' slank']
# appliances                                   ['hoge glazen', 'blender']
# main_ingredient                                               ijskoffie
# type                                                         ['koffie']
# Name: 18627, dtype: object
#
#
# [3072, 3246, 335, 10962, 15451]
# ['ijskoffie', 'chocorasp']
# IJskoffie met chocorasp

# %% [markdown]
# ## User interface test

# %%
from tkinter import *
from PIL import Image, ImageTk

# %%
def click():
    entered_text = textentry.get()
#     output.delete(0.0, END)
    recipes = retrieve(entered_text, [inverted_ingredients_dict, inverted_tags_dict, inverted_types_dict, inverted_title_dict],data)
    for i, element in enumerate(recipes):
#         Button(window, text=view_data.iloc[element,1], command = show_descr).grid(row=5+i)
        output.insert(END, view_data.iloc[element,1])
#         output.insert(END, description)
#         output.insert(END, '\n')
    
def show_descr():
    pass

window = Tk()
window.title('Recepten zoeker')
window.configure(background='white')
window.geometry("{}x{}".format(window.winfo_screenwidth(), window.winfo_screenheight()))

image = Image.open("bestek.png")
photo1 = ImageTk.PhotoImage(Image.open("bestek.png"))
Label(window, image=photo1).grid(row=0,column = 0, columnspan = 4, sticky=W+E+N+S)

Label(window, text="Wat wil je eten vanavond?", font='none 24 bold').grid(row=1,column=0,columnspan = 4,sticky=E+W)

textentry = Entry(window, width = 55)
textentry.grid(row=3,column=0,columnspan = 4,sticky=W)

Button(window, text='Zoek recepten', width=13, command=click, bg='red', fg='black', font='none 18 bold').grid(row=3,column=0, columnspan=4,sticky=E)

# description = Button(window, text='Omschrijving')

Label(window, text='Gevonden recepten',font='none 18 bold').grid(row=4,column=0,sticky=E+W)

# output = Text(window, width=75, height=6, wrap=WORD)
output = Listbox(window, height = 15, width = 50)
output.grid(row=5,column=0,columnspan=2,sticky=E+W)

print(output.curselection())

window.mainloop()
# Out:
# ()
# id                                                              1185844
# title                         ['pastasalad', 'framboz', 'blauwaderkas']
# description           ['salad', 'pasta', ',', 'bietjes', ',', 'courg...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['framboz', 'castello blue', 'farfall', 'sladr...
# calories                                                            485
# protein                                                              18
# carbohydrates                                                        62
# fat                                                                  17
# saturated_fat                                                         5
# sodium                                                              495
# fiber                                                                 7
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         32
# recipe_instruction    Kook de pasta volgens de aanwijzingen op de ve...
# tags                        ['snel', ' zonder vlees/vis', ' italiaans']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 19747, dtype: object
#
#
# id                                                               824442
# title                                  ['pastasalad', 'kas', 'tuinbon']
# description           ['mediterran', 'recept', '.', 'vegetarisch', '...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijv', 'bosui', 'wittewijnazijn', 'suiker',...
# calories                                                            605
# protein                                                              20
# carbohydrates                                                        68
# fat                                                                  27
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         35
# rating                                                                3
# review_count                                                         43
# recipe_instruction    Kook de pasta beetgaar. Giet af en laat afkoel...
# tags                          ['vegetarisch', ' mediterraan', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 14198, dtype: object
#
#
# id                                                              1186061
# title                          ['pastasalad', 'broccoli', 'tonijnsaus']
# description           ['salad', 'van', 'pasta', ',', 'tonijn', ',', ...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['kappertjes', 'broccoli', 'rode ui', 'mayonai...
# calories                                                            485
# protein                                                              25
# carbohydrates                                                        31
# fat                                                                  28
# saturated_fat                                                         4
# sodium                                                              370
# fiber                                                                 6
# cooking_time                                                         25
# rating                                                                3
# review_count                                                         45
# recipe_instruction    Kook de eieren in 8 min. hard. Laat schrikken ...
# tags                           ['lactosevrij', ' budget', ' italiaans']
# appliances                                                           []
# main_ingredient                                          gekookte pasta
# type                                                         ['salade']
# Name: 6771, dtype: object
#
#
# id                                                               726340
# title                                          ['pastasalad', 'tonijn']
# description           ['schelpjespasta', 'tonijn', ',', 'ei', 'sperz...
# course                                                            lunch
# recipe_yield                                                          4
# ingredients           ['tomat', 'kropsla', 'sperziebon', 'schelpjesp...
# calories                                                            505
# protein                                                              32
# carbohydrates                                                        63
# fat                                                                  12
# saturated_fat                                                         3
# sodium                                                              280
# fiber                                                                 7
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        271
# recipe_instruction    Kook de pasta volgens de aanwijzigingen op de ...
# tags                  ['zonder vlees', ' wat eten we vandaag', ' kok...
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 19755, dtype: object
#
#
# id                                                               274250
# title                            ['pastasalad', 'zongedroogd', 'tomat']
# description           ['pastasalad', 'broccoli', ',', 'zongedroogd',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie extra vierge met knoflook en chili...
# calories                                                            725
# protein                                                              23
# carbohydrates                                                        64
# fat                                                                  42
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        114
# recipe_instruction    Kook de pasta in 7 min. beetgaar. Spoel de pas...
# tags                            ['vegetarisch', ' italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 13601, dtype: object
#
#
# id                                                              1112334
# title                                          ['pastasalad', 'niçois']
# description           ['salad', 'pasta', ',', 'ei', ',', 'sperziebon...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['pipe rigat', 'wittewijnazijn', 'gerookte mak...
# calories                                                            680
# protein                                                              31
# carbohydrates                                                        62
# fat                                                                  33
# saturated_fat                                                         7
# sodium                                                              305
# fiber                                                                 6
# cooking_time                                                         20
# rating                                                                2
# review_count                                                        208
# recipe_instruction    Kook de pasta volgens de aanwijzingen op de ve...
# tags                      ['lactosevrij', ' vooraf te maken', ' frans']
# appliances                                                           []
# main_ingredient                                                 niçoise
# type                                                         ['salade']
# Name: 14842, dtype: object
#
#
# id                                                               415788
# title                        ['pastasalad', 'zalm', 'sinaasappeldress']
# description           ['italiaan', 'recept', '.', 'hoofdgerecht', 'b...
# course                                                     hoofdgerecht
# recipe_yield                                                          6
# ingredients           ['zure rom', 'penn', 'broccoli', 'doperwt', 'g...
# calories                                                            400
# protein                                                              19
# carbohydrates                                                        55
# fat                                                                  10
# saturated_fat                                                         4
# sodium                                                              535
# fiber                                                                 7
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        105
# recipe_instruction    Kook de pasta in ruim kokend water met zout vo...
# tags                    ['slank', ' italiaans', ' wat eten we vandaag']
# appliances                                          ['vergiet', 'rasp']
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 8658, dtype: object
#
#
# id                                                              1178291
# title                 ['romig', 'penn', 'champignon', 'italiaan', 'k...
# description           ['romig', 'penn', 'champignon', ',', 'cherryto...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'saladenotenmix', 'penne rigat',...
# calories                                                            775
# protein                                                              19
# carbohydrates                                                        65
# fat                                                                  47
# saturated_fat                                                        15
# sodium                                                              170
# fiber                                                                 8
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         49
# recipe_instruction    Breng een pan water met zout aan de kook en ko...
# tags                        ['snel', ' zonder vlees/vis', ' italiaans']
# appliances                                                           []
# main_ingredient                                            penne rigate
# type                                                          ['pasta']
# Name: 17315, dtype: object
#
#
# id                                                              1186168
# title                   ['pasta', '-', 'radijssalad', 'pistachegehakt']
# description           ['penn', 'gehaktballetjes', 'pistachenot', ','...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['penn', 'dill', 'mager half-om-halfgehakt', '...
# calories                                                            800
# protein                                                              44
# carbohydrates                                                        69
# fat                                                                  37
# saturated_fat                                                        11
# sodium                                                              650
# fiber                                                                 7
# cooking_time                                                         15
# rating                                                                4
# review_count                                                         31
# recipe_instruction    Hak de noten fijn. Doe met het gehakt, zakje g...
# tags                        ['snel', ' wat eten we vandaag', ' bakken']
# appliances                                                           []
# main_ingredient                                            radijssalade
# type                                                         ['salade']
# Name: 15486, dtype: object
#
#
# id                                                               409664
# title                                        ['lauwwarm', 'pastasalad']
# description           ['italiaan', 'recept', '.', 'hoofdgerecht', 'b...
# course                                                     hoofdgerecht
# recipe_yield                                                          2
# ingredients           ['walnot', 'broccoliroosjes', 'casoncelli vers...
# calories                                                            700
# protein                                                              23
# carbohydrates                                                        51
# fat                                                                  35
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         10
# rating                                                                3
# review_count                                                         83
# recipe_instruction                                                  NaN
# tags                                   ['snel', ' italiaans', ' koken']
# appliances                                                           []
# main_ingredient                          Casoncelli verse gevulde pasta
# type                                                         ['salade']
# Name: 45, dtype: object
#
#
# id                                                                65886
# title                    ['zomer', 'pastasalad', 'gerookt', 'kipfilet']
# description           ['heerlijk', 'pastasalad', 'gerookt', 'kipfile...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['verfijnde cashewnoten gezout', 'fusilli', 'g...
# calories                                                            660
# protein                                                              29
# carbohydrates                                                        67
# fat                                                                  29
# saturated_fat                                                         4
# sodium                                                              800
# fiber                                                                 7
# cooking_time                                                         15
# rating                                                                3
# review_count                                                        904
# recipe_instruction    Kook de fusilli volgens de aanwijzingen op de ...
# tags                                    ['snel', ' picknick', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 11804, dtype: object
#
#
# id                                                              1185843
# title                       ['pastasalad', 'salami', 'haricot', 'vert']
# description           ['salad', 'pasta', ',', 'haricot', 'vert', ','...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['bruschettatopping gegrilde groent', 'goudsal...
# calories                                                            520
# protein                                                              22
# carbohydrates                                                        55
# fat                                                                  22
# saturated_fat                                                         8
# sodium                                                             1125
# fiber                                                                 7
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         50
# recipe_instruction    Kook de pasta volgens de aanwijzingen op de ve...
# tags                           ['snel', ' lactosevrij', ' mediterraan']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 19797, dtype: object
#
#
# id                                                               349656
# title                    ['lauwwarm', 'ooster', 'salad', 'tonijnsteak']
# description           ['recept', '.', 'hoofdgerecht', 'bevat', 'volg...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['rijst', 'chinese groentemix', 'tonijnsteak',...
# calories                                                            815
# protein                                                              48
# carbohydrates                                                        88
# fat                                                                  31
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                         27
# recipe_instruction                                                  NaN
# tags                                                         ['bakken']
# appliances                                                           []
# main_ingredient                                                  salade
# type                                                         ['salade']
# Name: 16118, dtype: object
#
#
# id                                                              1185842
# title                           ['pastasalad', 'artisjok', 'geitenkas']
# description           ['pastasalad', ',', 'gemaakt', 'van', 'fusilli...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['artisjokhart', 'geitenkaas 50+', 'volle yogh...
# calories                                                            520
# protein                                                              19
# carbohydrates                                                        60
# fat                                                                  21
# saturated_fat                                                         6
# sodium                                                              570
# fiber                                                                 7
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         74
# recipe_instruction    Kook de pasta volgens de aanwijzingen op de ve...
# tags                           ['snel', ' vegetarisch', ' mediterraan']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 8079, dtype: object
#
#
# id                                                               558494
# title                       ['noedelsalad', 'kokos', '-', 'pindadress']
# description           ['recept', '.', 'vegetarisch', 'bijgerecht', '...
# course                                                       bijgerecht
# recipe_yield                                                          6
# ingredients           ['woknoedel', 'bosuitjes', 'pindakas', 'citroe...
# calories                                                            335
# protein                                                              16
# carbohydrates                                                        34
# fat                                                                   9
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                         20
# recipe_instruction                                                  NaN
# tags                                          ['vegetarisch', ' koken']
# appliances                                                           []
# main_ingredient                                            noedelsalade
# type                                                         ['salade']
# Name: 3151, dtype: object
#
#
# id                                                              1185641
# title                 ['pastasalad', 'yoghurt', ',', 'baharat', 'aub...
# description           ['pastasalad', 'yoghurt', ',', 'baharat', 'aub...
# course                                                            lunch
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'penn', 'baharat', 'magere kwark...
# calories                                                            425
# protein                                                              15
# carbohydrates                                                        53
# fat                                                                  16
# saturated_fat                                                         2
# sodium                                                               70
# fiber                                                                 5
# cooking_time                                                         20
# rating                                                                3
# review_count                                                         20
# recipe_instruction    Kook de penne volgens de aanwijzingen op de ve...
# tags                                          ['vegetarisch', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 19825, dtype: object
#
#
# id                                                               307088
# title                    ['ratatouill', '-', 'pastasalad', 'vinaigret']
# description           ['recept', '.', 'vegetarisch', 'hoofdgerecht',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'gedroogde tijm', 'farfall', 'ra...
# calories                                                            605
# protein                                                              24
# carbohydrates                                                        64
# fat                                                                  28
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                         19
# recipe_instruction                                                  NaN
# tags                                           ['vegetarisch', ' oven']
# appliances                                         ['grote ovenschaal']
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 2544, dtype: object
#
#
# id                                                               561656
# title                             ['pastasalad', 'wild', 'roz', 'zalm']
# description           ['salad', 'van', 'farfall', ',', 'tuinerwt', '...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['wilde roze zalm', 'farfall', 'cherrytomat', ...
# calories                                                            475
# protein                                                              26
# carbohydrates                                                        68
# fat                                                                  11
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                        180
# recipe_instruction    Breng in een ruime pan water aan de kook en ko...
# tags                      ['snel', ' zonder vlees', ' vooraf te maken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 7476, dtype: object
#
#
# id                                                               387712
# title                      ['pastasalad', 'asperges', 'gerookt', 'kip']
# description           ['snell', 'pastasalad', 'van', 'farfall', ',',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'rode paprika', 'farfall', 'bals...
# calories                                                            490
# protein                                                              22
# carbohydrates                                                        60
# fat                                                                  18
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                         95
# recipe_instruction    Kook de pasta volgens de aanwijzingen op de ve...
# tags                                            ['italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 17374, dtype: object
#
#
# id                                                               189246
# title                                     ['tonijn', '-', 'pastasalad']
# description           ['pastasalad', 'tonijn', ',', 'sperziebon', ',...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['caesar dress', 'penn', 'kappertjes', 'tonijn...
# calories                                                            255
# protein                                                              10
# carbohydrates                                                        31
# fat                                                                  10
# saturated_fat                                                         1
# sodium                                                              440
# fiber                                                                 2
# cooking_time                                                         15
# rating                                                                3
# review_count                                                        158
# recipe_instruction    Kook de penne volgens de aanwijzingen op de ve...
# tags                           ['zonder vlees', ' italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 13059, dtype: object
#
#
# id                                                               733324
# title                                   ['pastasalad', 'tomat', 'tijm']
# description           ['salad', 'fusilli', ',', 'tomat', ',', 'mozza...
# course                                                       bijgerecht
# recipe_yield                                                          6
# ingredients           ['mini-mozzarellabolletjes', 'crème fraîch', '...
# calories                                                            590
# protein                                                              21
# carbohydrates                                                        66
# fat                                                                  26
# saturated_fat                                                        10
# sodium                                                              165
# fiber                                                                 4
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        159
# recipe_instruction    Kook de pasta volgens de aanwijzingen op de ve...
# tags                  ['zonder vlees/vis', ' vooraf te maken', ' ita...
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 9329, dtype: object
#
#
# id                                                                 8432
# title                         ['pasta', 'ansjovis', '-', 'olijvensaus']
# description           ['italiaan', 'recept', '.', 'hoofdgerecht', 'b...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['doperwten (diepvries)', 'olijvensalad', 'ans...
# calories                                                            540
# protein                                                              30
# carbohydrates                                                        80
# fat                                                                  11
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         78
# recipe_instruction                                                  NaN
# tags                                  ['snel', ' budget', ' italiaans']
# appliances                                                           []
# main_ingredient                                                   pasta
# type                                                          ['pasta']
# Name: 6261, dtype: object
#
#
# id                                                              1187325
# title                                            ['thom', 'kha', 'kip']
# description           ['tom', 'kha', 'kip', 'kastanjechampignon', ',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['basmatirijst', 'limoen', 'kastanjechampignon...
# calories                                                            690
# protein                                                              34
# carbohydrates                                                        64
# fat                                                                  32
# saturated_fat                                                        19
# sodium                                                              280
# fiber                                                                 5
# cooking_time                                                         20
# rating                                                                3
# review_count                                                         68
# recipe_instruction    Kook de rijst volgens de aanwijzingen op de ve...
# tags                    ['aziatisch', ' thais', ' wat eten we vandaag']
# appliances                                                           []
# main_ingredient                                                     kip
# type                                                          ['vlees']
# Name: 10598, dtype: object
#
#
# id                                                               336494
# title                            ['miesalad', 'wasabidress', 'tilapia']
# description           ['japan', 'recept', '.', 'hoofdgerecht', 'beva...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['rode paprika', 'veldsla', 'limoensap', 'tila...
# calories                                                            420
# protein                                                              31
# carbohydrates                                                        49
# fat                                                                  12
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                         36
# recipe_instruction                                                  NaN
# tags                                ['aziatisch', ' japans', ' bakken']
# appliances                                                           []
# main_ingredient                                               miesalade
# type                                                         ['salade']
# Name: 6870, dtype: object
#
#
# id                                                               392246
# title                              ['italiaan', 'pastasalad', 'salami']
# description           ['italiaan', 'salad', 'fusilli', 'tricolor', '...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['rode paprika', 'salami', 'gemarineerde artis...
# calories                                                            680
# protein                                                              24
# carbohydrates                                                        80
# fat                                                                  28
# saturated_fat                                                         9
# sodium                                                              885
# fiber                                                                 7
# cooking_time                                                         25
# rating                                                                3
# review_count                                                         70
# recipe_instruction    Kook de fusilli volgens de aanwijzingen op de ...
# tags                        ['vooraf te maken', ' italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 2572, dtype: object
#
#
# id                                                              1186939
# title                              ['pastasalad', 'parrano', 'snipper']
# description           ['pastaschotel', 'farfall', ',', 'gegrild', 'p...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['babyromainesla', 'gegrilde paprika', 'farfal...
# calories                                                            530
# protein                                                              20
# carbohydrates                                                        56
# fat                                                                  24
# saturated_fat                                                         7
# sodium                                                             1180
# fiber                                                                 4
# cooking_time                                                         15
# rating                                                                2
# review_count                                                          9
# recipe_instruction    Kook de pasta volgens de aanwijzingen op de ve...
# tags                     ['snel', ' italiaans', ' wat eten we vandaag']
# appliances                                                 ['grillpan']
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 6881, dtype: object
#
#
# id                                                               443122
# title                                  ['pastasalad', 'brie', 'walnot']
# description           ['salad', 'penn', ',', 'roombrie', ',', 'rod',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['walnot', 'radijs', 'roombrie', 'penne rigat'...
# calories                                                            870
# protein                                                              22
# carbohydrates                                                        55
# fat                                                                  60
# saturated_fat                                                        17
# sodium                                                              635
# fiber                                                                11
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        332
# recipe_instruction    Kook de penne volgens de aanwijzingen op de ve...
# tags                                     ['zonder vlees/vis', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 5683, dtype: object
#
#
# id                                                               270404
# title                                        ['pastasalad', 'zeefruit']
# description           ['farfall', 'komkommer', ',', 'sla', ',', 'oli...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie extra vierg', 'snackkomkommer', 'f...
# calories                                                            305
# protein                                                              14
# carbohydrates                                                        23
# fat                                                                  18
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                         13
# recipe_instruction    Kook de pasta beetgaar volgens de aanwijzingen...
# tags                                            ['italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 737, dtype: object
#
#
# id                                                              1154200
# title                 ['thais', 'scholspiesjes', 'kruidig', 'rijst',...
# description           ['spies', 'van', 'paprika', ',', 'bosui', 'sch...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['winterpen', 'scholfilet', 'gele paprika', 'r...
# calories                                                            495
# protein                                                              22
# carbohydrates                                                        70
# fat                                                                  12
# saturated_fat                                                         3
# sodium                                                              550
# fiber                                                                 9
# cooking_time                                                         25
# rating                                                                3
# review_count                                                         23
# recipe_instruction    Kook de pandanrijst volgens de aanwijzingen op...
# tags                    ['aziatisch', ' thais', ' wat eten we vandaag']
# appliances              ['8 sateprikkers', 'keukenmachine', 'grillpan']
# main_ingredient                                           scholspiesjes
# type                                                         ['salade']
# Name: 6281, dtype: object
#
#
# id                                                               397382
# title                               ['pastasalad', 'tonijn', 'courget']
# description           ['pastasalad', 'tonijn', ',', 'zongedroogd', '...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['pijnboompit', 'penne rigat', 'tonijnstukjes ...
# calories                                                            700
# protein                                                              41
# carbohydrates                                                        80
# fat                                                                  24
# saturated_fat                                                         3
# sodium                                                              805
# fiber                                                                 7
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        284
# recipe_instruction    Penne volgens gebruiksaanwijzing koken, in ver...
# tags                           ['zonder vlees', ' italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 2597, dtype: object
#
#
# id                                                               543132
# title                                   ['gehaktkoekjes', 'pastasalad']
# description           ['italiaan', 'recept', '.', 'hoofdgerecht', 'b...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['tomatenketchup', 'courget', 'pomodori', 'pen...
# calories                                                            660
# protein                                                              31
# carbohydrates                                                        73
# fat                                                                  27
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                         36
# recipe_instruction    Laat de pomodori al forno uitlekken, vang het ...
# tags                  ['italiaans', ' wat eten we vandaag', ' grillen']
# appliances                                                 ['grillpan']
# main_ingredient                                           gehaktkoekjes
# type                                                         ['salade']
# Name: 11887, dtype: object
#
#
# id                                                              1185816
# title                      ['pastasalad', 'vadouvan', ',', 'ei', 'kip']
# description           ['italiaan', 'pastasalad', 'vadouvan', ',', 'e...
# ...
# rating                                                                3
# review_count                                                        104
# recipe_instruction    Kook de pasta volgens de aanwijzingen op de ve...
# tags                                            ['italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 556, dtype: object
#
#
# id                                                               231654
# title                                          ['pastasalad', 'tonijn']
# description           ['pastasalad', 'tonijn', ',', 'kappertjes', ',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['penn', 'kappertjes', 'broccoli', 'zwarte oli...
# calories                                                            485
# protein                                                              21
# carbohydrates                                                        49
# fat                                                                  23
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        286
# recipe_instruction    Kook de penne in ca. 12 min. beetgaar. Verdeel...
# tags                                            ['italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 10456, dtype: object
#
#
# id                                                               554054
# title                                  ['pastasalad', 'snijbon', 'kas']
# description           ['recept', '.', 'vegetarisch', 'hoofdgerecht',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['holland', 'italiaan', 'farfall', 'mayonais',...
# calories                                                            605
# protein                                                              25
# carbohydrates                                                        62
# fat                                                                  29
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                         73
# recipe_instruction    Kook de farfalle volgens de aanwijzingen op de...
# tags                  ['vegetarisch', ' wat eten we vandaag', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 9208, dtype: object
#
#
# id                                                               710892
# title                        ['wit', 'pastasalad', 'gepoft', 'knoflok']
# description           ['italiaan', 'recept', '.', 'vegetarisch', 'bi...
# course                                                       bijgerecht
# recipe_yield                                                          8
# ingredients           ['olijfolie', 'farfall', 'knoflok', 'zoete ui'...
# calories                                                            400
# protein                                                              10
# carbohydrates                                                        49
# fat                                                                  18
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                         53
# recipe_instruction    Verwarm de oven voor op 180 °C. Snijd de boven...
# tags                             ['vegetarisch', ' oven', ' italiaans']
# appliances                        ['ovenschaaltje doorsnede ca. 10 cm']
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 3679, dtype: object
#
#
# id                                                               444882
# title                       ['tomatenfrittata', 'uit', 'oven', 'salad']
# description           ['span', 'recept', '.', 'vegetarisch', 'hoofdg...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'gemalen pastakas', 'gemengde ij...
# calories                                                            740
# protein                                                              32
# carbohydrates                                                        54
# fat                                                                  44
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                         20
# recipe_instruction                                                  NaN
# tags                                ['vegetarisch', ' oven', ' spaans']
# appliances                                                 ['bakplaat']
# main_ingredient                                                    oven
# type                                                         ['salade']
# Name: 3053, dtype: object
#
#
# id                                                               190410
# title                                            ['pastasalad', 'zalm']
# description                                      ['pastasalad', 'zalm']
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['thousand islands sladress', 'farfall', 'spin...
# calories                                                            535
# protein                                                              26
# carbohydrates                                                        58
# fat                                                                  22
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        151
# recipe_instruction                                                  NaN
# tags                                                          ['koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 3063, dtype: object
#
#
# id                                                               396260
# title                                          ['pastasalad', 'tonijn']
# description           ['pastasalad', 'tonijn', ',', 'sperziebon', ',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['mosterd', 'knoflok', 'sperziebon', 'ansjovis...
# calories                                                            505
# protein                                                              34
# carbohydrates                                                        54
# fat                                                                  17
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        418
# recipe_instruction    Kook de pasta volgens de aanwijzing op de verp...
# tags                                            ['italiaans', ' koken']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 7996, dtype: object
#
#
# id                                                              1186021
# title                   ['pastasalad', 'ham', ',', 'courget', 'perzik']
# description           ['pastasalad', 'parmaham', ',', 'courget', ','...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', '(wilde) perzik', 'selderij', 'b...
# calories                                                            710
# protein                                                              29
# carbohydrates                                                        71
# fat                                                                  33
# saturated_fat                                                        11
# sodium                                                              520
# fiber                                                                 5
# cooking_time                                                         35
# rating                                                                3
# review_count                                                         67
# recipe_instruction    Kook de pasta volgens de aanwijzingen op de ve...
# tags                                          ['italiaans', ' grillen']
# appliances                                                 ['grillpan']
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 3700, dtype: object
#
#
# id                                                              1187748
# title                 ['macaroni', 'ham', ',', 'kas', ',', 'bloemkoo...
# description           ['pastagerecht', 'tuinerwt', ',', 'bloemkoolri...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'hamblokjes', 'salade-ui', 'bloe...
# calories                                                            650
# protein                                                              38
# carbohydrates                                                        67
# fat                                                                  24
# saturated_fat                                                        12
# sodium                                                              850
# fiber                                                                 8
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         37
# recipe_instruction    Kook de macaroni in een ruime pan volgens de a...
# tags                     ['snel', ' italiaans', ' wat eten we vandaag']
# appliances                                                           []
# main_ingredient                                                macaroni
# type                                                          ['pasta']
# Name: 5558, dtype: object
#
#
# id                                                               377940
# title                 ['pastasalad', 'geroosterd', 'groent', 'geiten...
# description           ['vegetarisch', 'pastasalad', 'van', 'farfall'...
# course                                                       bijgerecht
# recipe_yield                                                          4
# ingredients           ['winterpen', 'olijfolie', 'farfall', 'rucolas...
# calories                                                            480
# protein                                                              14
# carbohydrates                                                        55
# fat                                                                  22
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         40
# rating                                                                3
# review_count                                                         37
# recipe_instruction    Verwarm de oven voor op 225 ºC. Snijd de knols...
# tags                             ['vegetarisch', ' oven', ' italiaans']
# appliances                                                           []
# main_ingredient                                             pastasalade
# type                                                         ['salade']
# Name: 1832, dtype: object
#
#
# id                                                              1187452
# title                                          ['pastasalad', 'niçois']
# description           ['heerlijk', 'pastasalad', 'niçois', '.', 'com...
# course                                                            lunch
# recipe_yield                                                          4
# ingredients           ['garnal', 'volle yoghurt', 'ei', 'rauwkost ko...
# calories                                                            355
# protein                                                              25
# carbohydrates                                                        34
# fat                                                                  12
# saturated_fat                                                         3
# sodium                                                              855
# fiber                                                                 5
# cooking_time                                                         20
# rating                                                                2
# review_count                                                          8
# recipe_instruction    Kook de eieren in 8 min. hard. Laat ze schrikk...
# tags                                      ['slank', ' vooraf te maken']
# appliances                                                           []
# main_ingredient                                                 niçoise
# type                                                         ['salade']
# Name: 13576, dtype: object
