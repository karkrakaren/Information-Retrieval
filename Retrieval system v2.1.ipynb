# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast
from nltk.tokenize import wordpunct_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer

# %% [markdown]
# #### Load in data

# %%
data = pd.read_csv('allerhande_preprocessed.csv', index_col=0)
print(data.head())
# Out:
#         id                                   title  \
# 0   861106            ['vegetarisch', 'bonenstof']
# 1   680104                   ['fris', 'limoenrom']
# 2   683858  ['kalkoenfilet', 'champignonroomsaus']
# 3  1187074     ['andijvie', 'rauw', 'ham', 'prei']
# 4   660152        ['spruit', '-', 'rozijnensalad']
#
#                                          description        course  \
# 0  ['stoofgerecht', 'vegetarisch', 'balletjes', '...  hoofdgerecht
# 1  ['recept', '.', 'nagerecht', 'bevat', 'volgend...     nagerecht
# 2  ['kidsprof', 'winter', 'recept', 'pasta', 'kal...  hoofdgerecht
# 3  ['bijgerecht', 'andijvie', ',', 'prei', ',', '...    bijgerecht
# 4  ['holland', 'recept', '.', 'vegetarisch', 'bij...    bijgerecht
#
#    recipe_yield                                        ingredients  calories  \
# 0           4.0  ['olijfolie', 'tomatenblokjes', 'bruine bon', ...     410.0
# 1           4.0  ['limoen', 'slagrom', 'vloeibare hon', 'grieks...     290.0
# 2           4.0  ['olijfolie', 'gedroogde rozemarijn', 'champig...     585.0
# 3           4.0  ['olijfolie', 'prei', 'knoflok', 'fijngesneden...     175.0
# 4           4.0  ['sladressing bieslok', 'spruitjes', 'bosui', ...     115.0
#
#    protein  carbohydrates   fat  saturated_fat  sodium  fiber  cooking_time  \
# 0     21.0           52.0  10.0            2.0  1040.0   16.0          15.0
# 1      8.0           14.0  22.0            NaN     NaN    NaN          10.0
# 2     41.0           58.0  21.0            0.0     NaN    NaN          25.0
# 3      9.0            7.0  11.0            2.0   475.0    6.0          15.0
# 4      1.0           19.0   4.0            0.0     NaN    NaN          15.0
#
#    rating  review_count                                 recipe_instruction  \
# 0     3.0         483.0                    Verwarm de oven voor op 200 ºC.
# 1     3.0         161.0                                                NaN
# 2     3.0         112.0  Kook de spaghetti volgens de aanwijzingen op d...
# 3     3.0           8.0  Was de preien en snijd ze in ringen. Snijd de ...
# 4     3.0          58.0  Verwijder de buitenste bladeren van de spruite...
#
#                                                tags  \
# 0                ['vegetarisch', ' slank', ' oven']
# 1                                         ['kerst']
# 2  ['italiaans', ' wat eten we vandaag', ' bakken']
# 3       ['glutenvrij', ' lactosevrij', ' hollands']
# 4            ['vegetarisch', ' hollands', ' koken']
#
#                     appliances          type
# 0  ['ovenschaal (20 x 30 cm)']  ['stoofpot']
# 1              ['hoge glazen']     ['fruit']
# 2                           []     ['vlees']
# 3                           []     ['vlees']
# 4                           []    ['salade']

# %%
view_data = pd.read_csv('allerhande_raw.csv', index_col=0)
print(view_data.head())
view_data.drop_duplicates(subset='id', inplace=True)
# Out:
#         id                                title  \
# 0   861106              Vegetarische bonenstoof
# 1   680104                    Frisse limoenroom
# 2   683858  Kalkoenfilet met champignonroomsaus
# 3  1187074       Andijvie met rauwe ham en prei
# 4   660152              Spruiten-rozijnensalade
#
#                                          description        course  \
# 0  Stoofgerecht met vegetarische balletjes, aarda...  hoofdgerecht
# 1  Een lekker recept. Het nagerecht bevat de volg...     nagerecht
# 2  Kidsproof winters recept voor pasta met kalkoe...  hoofdgerecht
# 3  bijgerecht met andijvie, prei, knoflook, tijm ...    bijgerecht
# 4  Een lekker hollands recept. Het vegetarische b...    bijgerecht
#
#   recipe_yield                                        ingredients calories  \
# 0   4 personen  {'olijfolie': '2 el()', 'tomatenblokjes': '800...  410kcal
# 1   4 personen  {'limoenen': ' 2(schoongeboend)', 'slagroom': ...  290kcal
# 2   4 personen  {'olijfolie': '2 el()', 'gedroogde rozemarijn'...  585kcal
# 3   4 personen  {'olijfolie': '2 el()', 'prei': '2 ()', 'knofl...  175kcal
# 4   4 personen  {'sladressing bieslook': '6 el(fles 270 ml)', ...  115kcal
#
#   protein carbohydrates  fat saturated_fat   sodium fiber      cooking_time  \
# 0     21g           52g  10g            2g  1.040mg   16g  15 min. bereiden
# 1      8g           14g  22g           NaN      NaN   NaN  10 min. bereiden
# 2     41g           58g  21g            0g      NaN   NaN  25 min. bereiden
# 3      9g            7g  11g            2g    475mg    6g  15 min. bereiden
# 4      1g           19g   4g            0g      NaN   NaN  15 min. bereiden
#
#    rating  review_count                                 recipe_instruction  \
# 0     3.0         483.0                    Verwarm de oven voor op 200 ºC.
# 1     3.0         161.0                                                NaN
# 2     3.0         112.0  Kook de spaghetti volgens de aanwijzingen op d...
# 3     3.0           8.0  Was de preien en snijd ze in ringen. Snijd de ...
# 4     3.0          58.0  Verwijder de buitenste bladeren van de spruite...
#
#                                               source  \
# 0  Allerhande magazine 2012 nr. 11 - Alles uit de...
# 1  Allerhande magazine 2010 nr. 12 - Kerst nieuw-...
# 2                        Receptkaart 2010 week 50-51
# 3     Allerhande magazine 2016 nr. 05 - Eet de lente
# 4  Allerhande magazine 2010 nr. 09 - Groente volo...
#
#                                              tags                   appliances
# 0                ['vegetarisch', 'slank', 'oven']  ['ovenschaal (20 x 30 cm)']
# 1                                       ['kerst']              ['hoge glazen']
# 2  ['italiaans', 'wat eten we vandaag', 'bakken']                           []
# 3       ['glutenvrij', 'lactosevrij', 'hollands']                           []
# 4            ['vegetarisch', 'hollands', 'koken']                           []

# %% [markdown]
# #### Load in inverted columns and convert to dict

# %%
inverted_ingredients_pd = pd.read_csv('inverted_list_ingredients.csv', header=None, names=['Word', 'Index'])
print(inverted_ingredients_pd.head())
inverted_ingredients_dict = pd.Series(inverted_ingredients_pd.Index.values,index=inverted_ingredients_pd.Word).to_dict()
# Out:
#                                        Word  \
# 0                                datterrini
# 1                  mexicaanse roerbakgroent
# 2                  zachte boter of margarin
# 3  stoomgroenten (broccoli/rode ui/paprika)
# 4                             bruine suiker
#
#                                                Index
# 0                                             [6320]
# 1  [537, 847, 1473, 1544, 2056, 2511, 6391, 6492,...
# 2            [3262, 6202, 6579, 13639, 15010, 16674]
# 3                                            [10181]
# 4  [1442, 2110, 7265, 8615, 9369, 10257, 11532, 1...

# %%
inverted_tags_pd = pd.read_csv('inverted_list_tags.csv', header=None, names=['Word', 'Index'])
# remove row with value NaN
index_nr = []
for i, word in enumerate(inverted_tags_pd['Word']):
    if type(word) is not str:
        index_nr.append(i)
inverted_tags_pd.drop(index_nr, inplace=True)
print(inverted_tags_pd.head())
inverted_tags_dict = pd.Series(inverted_tags_pd.Index.values,index=inverted_tags_pd.Word).to_dict()
# Out:
#                 Word                                              Index
# 1              slank  [0, 45, 67, 135, 172, 221, 260, 344, 369, 386,...
# 2        advertorial                                       [5741, 7705]
# 3   sinterklaasavond  [572, 585, 960, 1132, 1583, 1890, 2594, 3162, ...
# 4        mediterraan  [8, 108, 211, 334, 344, 462, 470, 474, 514, 57...
# 5              turks  [660, 812, 1294, 1425, 1622, 2150, 2170, 2983,...

# %%
inverted_types_pd = pd.read_csv('inverted_list_types.csv', header=None, names=['Word', 'Index'])
print(inverted_types_pd.head())
inverted_types_dict = pd.Series(inverted_types_pd.Index.values,index=inverted_types_pd.Word).to_dict()
# Out:
#         Word                                              Index
# 0       koek  [102, 134, 228, 648, 690, 749, 888, 976, 1005,...
# 1  carpaccio  [11, 19, 23, 34, 778, 1285, 1533, 1644, 1796, ...
# 2         ei  [41, 51, 218, 270, 294, 443, 485, 522, 533, 65...
# 3  chocolade  [371, 2462, 3250, 4764, 5339, 5858, 7796, 9814...
# 4   cocktail  [427, 828, 926, 1251, 1558, 1650, 1818, 2000, ...

# %%
inverted_title_pd = pd.read_csv('inverted_list_title.csv', header=None, names=['Word', 'Index'])
print(inverted_title_pd.head())
index_nr = []
for i, word in enumerate(inverted_title_pd['Word']):
    if type(word) is not str:
        index_nr.append(i)
print(index_nr)
print(len(inverted_title_pd['Word']))
# print(index_nr)
inverted_title_pd.drop(index_nr, inplace=True)
inverted_title_dict = pd.Series(inverted_title_pd.Index.values,index=inverted_title_pd.Word).to_dict()
# Out:
#             Word   Index
# 0     peulvrucht  [2591]
# 1   puntasperges  [3194]
# 2    advertorial  [7918]
# 3       pantosti  [6045]
# 4  kaascroissant  [2751]
# [2668]
# 8694

# %% [markdown]
# #### First for only one word in only one inverted column

# %%
# word = str, inverted_column = dict, retrieved_docs = list
def retrieve_inverted_column(word, inverted_column):
    retrieved_docs = []
    for key in inverted_column.keys():
        if word in key:
            retrieved_docs += ast.literal_eval(inverted_column.get(key))
    return list(set(retrieved_docs))

# %% [markdown]
# ## Retrieval system
# - tokenize query, remove all tokens that have len = 1, since these are not words
# - for each word in query, create set of documents containing this word
#     - look through each inverted column to retrieve possible documents
# - get the intersection of the document sets of each word to only retrieve documents with all query words
# - print all retrieved documents

# %%
# query = str, inverted_column = list of dicts?
def retrieve(query, inverted_columns, dataset):
    tokens = word_tokenize(query)
    words = [item for item in tokens if len(item) > 1]
    
    # lowercase & stemmen
    words = [y.lower() for y in words]
    stemmer = SnowballStemmer("dutch")
    words = [stemmer.stem(y) for y in words]
    
    set_per_word = []
    
    # loop through query words
    for word in words:
        
        # get set of retrieved docs for each word
        retrieved_docs_word = []
        for column in inverted_columns:
            retrieved_docs_word += retrieve_inverted_column(word, column)
        set_per_word.append(set(retrieved_docs_word))
    
    # get intersection of sets for whole query
    retrieved = set_per_word[0]
    for element in set_per_word[1:]:
        retrieved = retrieved.intersection(element)
        
    # print all retrieved recipes
    for index in retrieved:
        print(dataset.iloc[index,:])
        print('\n')
        
    return list(retrieved)

# %%
test1 = retrieve("ijskoffie", [inverted_ingredients_dict, inverted_tags_dict, inverted_types_dict, inverted_title_dict],data)
print(test1)
print(data.iloc[test1[0],1])
print(view_data.iloc[test1[0],1])
# Out:
# id                                                               549844
# title                                        ['ijskoffie', 'chocorasp']
# description           ['recept', '.', 'vegetarisch', 'nagerecht', 'b...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients                   ['sterke koffie', 'pure chocolad', 'ijs']
# calories                                                            105
# protein                                                               2
# carbohydrates                                                        12
# fat                                                                   6
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                          5
# rating                                                                3
# review_count                                                         92
# recipe_instruction                                                  NaN
# tags                                                    ['vegetarisch']
# appliances                                            ['4 hoge glazen']
# type                                                            ['ijs']
# Name: 3714, dtype: object
#
#
# id                                                               208532
# title                                      ['ijskoffie', 'advocaatrom']
# description           ['recept', '.', 'vegetarisch', 'nagerecht', 'b...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['vanillesuiker', 'scharreladvocat', 'cafe au ...
# calories                                                            325
# protein                                                               5
# carbohydrates                                                        32
# fat                                                                  19
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         10
# rating                                                                3
# review_count                                                         16
# recipe_instruction                                                  NaN
# tags                                                    ['vegetarisch']
# appliances                                                           []
# type                                                            ['ijs']
# Name: 3926, dtype: object
#
#
# id                                                               140226
# title                                                     ['ijskoffie']
# description           ['recept', '.', 'vegetarisch', 'nagerecht', 'b...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients               ['vanilleroomijs', 'likeur', 'hete espresso']
# calories                                                            NaN
# protein                                                             NaN
# carbohydrates                                                       NaN
# fat                                                                 NaN
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                          5
# rating                                                                2
# review_count                                                         18
# recipe_instruction                                                  NaN
# tags                                          ['kerst', ' vegetarisch']
# appliances                                                           []
# type                                                            ['ijs']
# Name: 400, dtype: object
#
#
# id                                                               468752
# title                                    ['ijskoffie', 'lobbig', 'rom']
# description           ['recept', '.', 'vegetarisch', 'nagerecht', 'b...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['suiker', 'slagrom', 'ijsklontjes', 'koffie',...
# calories                                                            274
# protein                                                               2
# carbohydrates                                                        17
# fat                                                                  22
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         10
# rating                                                                3
# review_count                                                         32
# recipe_instruction                                                  NaN
# tags                                                    ['vegetarisch']
# appliances                                                           []
# type                                                            ['ijs']
# Name: 13214, dtype: object
#
#
# id                                                               517076
# title                                                     ['ijskoffie']
# description           ['recept', '.', 'vegetarisch', 'nagerecht', 'b...
# course                                                        nagerecht
# recipe_yield                                                          4
# ingredients           ['kaneelpoeder', 'chocoladestick', 'witte bast...
# calories                                                              0
# protein                                                               0
# carbohydrates                                                         0
# fat                                                                   0
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         84
# recipe_instruction                                                  NaN
# tags                                ['kerst', ' vegetarisch', ' slank']
# appliances                                   ['hoge glazen', 'blender']
# type                                                            ['ijs']
# Name: 18627, dtype: object
#
#
# [3072, 3246, 335, 10962, 15451]
# ['ijskoffie', 'chocorasp']
# IJskoffie met chocorasp

# %% [markdown]
# ## User interface test

# %%
from tkinter import *
from PIL import Image, ImageTk

# %%
# Function to retrieve recipes
def click():
    entered_text = textentry.get()
    results.delete(0, END)
    information.delete(0.0, END)
    global recipes
    recipes = retrieve(entered_text, [inverted_ingredients_dict, inverted_tags_dict, inverted_types_dict, inverted_title_dict],data)
    for i, element in enumerate(recipes):
        results.insert(END, view_data.iloc[element,1])

# Function to show additional information for the selected recipe
def show_descr():
    selected_recipe = results.curselection()
    recipe_index = recipes[int(selected_recipe[0])]
    information.delete(0.0, END)
    information.insert(END, "Omschrijving \n", 'big')
    information.insert(END, view_data.iloc[recipe_index,2] + '\n', 'normal')
    information.insert(END, '\nIngrediënten \n', 'big')
    for ingredient in ast.literal_eval(view_data.iloc[recipe_index,5]):
        information.insert(END, ingredient + '\n', 'normal')
    

# General window settings
window = Tk()
window.title('Recepten zoeker v.1')
window.configure(background='white')
window.geometry("{}x{}".format(window.winfo_screenwidth(), window.winfo_screenheight()))

image = Image.open("bestek.png")
photo1 = ImageTk.PhotoImage(Image.open("bestek.png"))
Label(window, image=photo1).grid(row=0,column = 0, columnspan = 4, sticky=W+E+N+S)

Label(window, text="Wat wil je eten vanavond?", font='none 24 bold').grid(row=1,column=0,columnspan = 4,sticky=E+W)

# Query box
textentry = Entry(window, width = 75)
textentry.grid(row=3,column=0,columnspan = 4,sticky=W)

Button(window, text='Zoek recepten', width=13, command=click, font='none 18 bold').grid(row=3,column=2,sticky=W)

Label(window, text='Gevonden recepten',font='none 18 bold').grid(row=4,column=0,sticky=E+W)

# Box that shows all retrieved recipes
results = Listbox(window, height = 15, width = 75)
results.grid(row=5,column=0,columnspan=2,sticky=E+W)

# Box that shows additional information about recipe
information = Text(window, width=75, height=15, wrap=WORD)
information.tag_configure('big', font=('none', 16, 'bold'))
information.tag_configure('normal', font=('none', 16))
information.grid(row=5, column=2, columnspan=2, sticky=E+W)

Button(window, text="Klik hier om meer informatie te krijgen over het geselecteerde recept", command=show_descr, font='none 16 bold').grid(row=6, column=0, columnspan=2, sticky=W)

window.mainloop()
# Out:
# id                                                               189252
# title                                     ['lasagn', 'kalkoen', 'prei']
# description           ['italiaan', 'recept', '.', 'hoofdgerecht', 'b...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['gesneden prei', 'melk', 'gemalen belegen kas...
# calories                                                            580
# protein                                                              47
# carbohydrates                                                        45
# fat                                                                  23
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                         63
# recipe_instruction                                                  NaN
# tags                                             ['oven', ' italiaans']
# appliances                            ['ovenschaal inhoud ca. 2 liter']
# type                                                        ['lasagne']
# Name: 6770, dtype: object
#
#
# id                                                                 8346
# title                                  ['lasagnepakketjes', 'raapstel']
# description           ['recept', '.', 'voorgerecht', 'bevat', 'volge...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['raapstel', 'ah grote garnal', 'boter', 'prei...
# calories                                                            220
# protein                                                              11
# carbohydrates                                                        15
# fat                                                                  13
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                         32
# recipe_instruction     Worteltjes van raapstelen snijden. Raapstelen...
# tags                                               ['budget', ' koken']
# appliances                                                           []
# type                                                        ['lasagne']
# Name: 3088, dtype: object
#
#
# id                                                               534960
# title                                             ['lasagn', 'ricotta']
# description           ['rijkgevuld', 'lasagn', 'fris', ',', 'zacht',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'tomatenblokjes', 'ricotta', 'kn...
# calories                                                            655
# protein                                                              28
# carbohydrates                                                        59
# fat                                                                  33
# saturated_fat                                                        17
# sodium                                                              725
# fiber                                                                 4
# cooking_time                                                         30
# rating                                                                3
# review_count                                                       1275
# recipe_instruction    Verwarm de oven voor op 175 °C. Snipper de ui ...
# tags                  ['zonder vlees/vis', ' vooraf te maken', ' oven']
# appliances                      ['grillpan', 'ovenschaal (20 x 30 cm)']
# type                                                        ['lasagne']
# Name: 17296, dtype: object
#
#
# id                                                               370816
# title                                     ['lasagn', 'ham', 'broccoli']
# description           ['lasagn', 'broccoli', ',', 'mozzarella', ',',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['lasagneblad', 'broccoli', 'gemalen belegen k...
# calories                                                            715
# protein                                                              47
# carbohydrates                                                        63
# fat                                                                  30
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         10
# rating                                                                3
# review_count                                                         82
# recipe_instruction    Verwam de oven voor op 200 °C. Maak de broccol...
# tags                                             ['oven', ' italiaans']
# appliances                                                           []
# type                                                        ['lasagne']
# Name: 628, dtype: object
#
#
# id                                                               759060
# title                                            ['opgerold', 'lasagn']
# description           ['lasagn', 'spinazie', ',', 'kastanjechampigno...
# course                                                     hoofdgerecht
# recipe_yield                                                          6
# ingredients           ['olijfolie', 'verse lasagneblad', 'pijnboompi...
# calories                                                            715
# protein                                                              33
# carbohydrates                                                        45
# fat                                                                  43
# saturated_fat                                                        18
# sodium                                                              435
# fiber                                                                 7
# cooking_time                                                         40
# rating                                                                3
# review_count                                                        380
# recipe_instruction    Verwarm de oven voor op 180 °C. Snijd de knofl...
# tags                        ['zonder vlees/vis', ' oven', ' italiaans']
# appliances                                     ['ovenschaal (Ø 32 cm)']
# type                                                        ['lasagne']
# Name: 6785, dtype: object
#
#
# id                                                              1185683
# title                                      ['lasagn', 'in', 'a', 'jar']
# description                   ['italiaan', 'lasagn', 'in', 'potj', '.']
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['verse lasagneblad', 'boter', 'italiaanse roe...
# calories                                                            885
# protein                                                              42
# carbohydrates                                                        68
# fat                                                                  48
# saturated_fat                                                        22
# sodium                                                             2050
# fiber                                                                 6
# cooking_time                                                         40
# rating                                                                3
# review_count                                                         27
# recipe_instruction    Snijd het ontbijtspek in reepjes. Verhit een h...
# tags                        ['kerst', ' vooraf te maken', ' italiaans']
# appliances                     ['4 weckpotten (à 500 ml)', 'magnetron']
# type                                                        ['lasagne']
# Name: 16075, dtype: object
#
#
# id                                                               743386
# title                 ['open', 'lasagn', 'pesto', ',', 'pecorino', '...
# description           ['open', 'italiaan', 'lasagn', 'pesto', ',', '...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'verse lasagneblad', 'pijnboompi...
# calories                                                            555
# protein                                                              21
# carbohydrates                                                        35
# fat                                                                  36
# saturated_fat                                                        10
# sodium                                                              595
# fiber                                                                 3
# cooking_time                                                         30
# rating                                                                3
# review_count                                                        245
# recipe_instruction    Snipper de ui en snijd 2 tenen knoflook fijn. ...
# tags                       ['zonder vlees/vis', ' italiaans', ' koken']
# appliances                                            ['keukenmachine']
# type                                                        ['lasagne']
# Name: 6787, dtype: object
#
#
# id                                                               324192
# title                 ['lasagn', 'ricotta', ',', 'spinazie', 'gerook...
# description           ['italiaan', 'ovengerecht', 'zalm', ',', 'rico...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'geraspte oude kas', 'tomat', 'r...
# calories                                                            750
# protein                                                              50
# carbohydrates                                                        49
# fat                                                                  37
# saturated_fat                                                        14
# sodium                                                             1025
# fiber                                                                 5
# cooking_time                                                         15
# rating                                                                3
# review_count                                                       1203
# recipe_instruction    Snipper de ui. Verhit de olie in een wok en fr...
# tags                      ['zonder vlees', ' vooraf te maken', ' oven']
# appliances                                  ['ovenschaal (20 x 30 cm)']
# type                                                        ['lasagne']
# Name: 2485, dtype: object
#
#
# id                                                              1186129
# title                                ['zucchini', 'alla', 'parmigiana']
# description           ['lasagn', 'courgetteplakjes', 'als', "'", 'la...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['mozzarella', 'panko', 'balsamicoazijn', 'kno...
# calories                                                            560
# protein                                                              31
# carbohydrates                                                        35
# fat                                                                  32
# saturated_fat                                                        13
# sodium                                                              840
# fiber                                                                 5
# cooking_time                                                         30
# rating                                                                3
# review_count                                                         68
# recipe_instruction    Verwarm de oven voor op 180 °C. Snijd de ui in...
# tags                        ['zonder vlees/vis', ' oven', ' italiaans']
# appliances                                                 ['grillpan']
# type                                                        ['lasagne']
# Name: 13602, dtype: object
#
#
# id                                                               423038
# title                        ['snell', 'lasagn', 'sardines', 'paprika']
# description           ['snell', 'lasagn', 'sardines', ',', 'paprika'...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['sardinefilet', 'lasagneblad', 'paprikamix', ...
# calories                                                            600
# protein                                                              26
# carbohydrates                                                        77
# fat                                                                  21
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         62
# recipe_instruction    Verwarm de oven voor op 200 °C. Maak de paprik...
# tags                                             ['oven', ' italiaans']
# appliances                               ['ovenschaal (ca. 2.5 liter)']
# type                                                        ['lasagne']
# Name: 17925, dtype: object
#
#
# id                                                               361572
# title                      ['hartenlasagn', 'tomat', '-', 'gehaktsaus']
# description           ['lasagn', 'in', 'hartvorm', 'tomatengehaktsau...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'tomatenpuree', 'knoflok', 'toma...
# calories                                                            670
# protein                                                              40
# carbohydrates                                                        42
# fat                                                                  37
# saturated_fat                                                        15
# sodium                                                              520
# fiber                                                                 3
# cooking_time                                                         40
# rating                                                                3
# review_count                                                         46
# recipe_instruction    Snipper de ui en snijd de knoflook fijn. Verhi...
# tags                         ['italiaans', ' valentijnsdag', ' bakken']
# appliances                                                           []
# type                                                        ['lasagne']
# Name: 17320, dtype: object
#
#
# id                                                              1187050
# title                        ['lasagn', 'geitenkaasricotta', 'courget']
# description           ['lasagn', 'zonder', 'vles', 'vis', ',', 'mar'...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['verse lasagneblad', 'ricotta', 'geraspte gei...
# calories                                                            595
# protein                                                              25
# carbohydrates                                                        58
# fat                                                                  28
# saturated_fat                                                        16
# sodium                                                              660
# fiber                                                                 5
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         48
# recipe_instruction    Verwarm de oven voor op 190 °C. Verhit de olie...
# tags                  ['zonder vlees/vis', ' vooraf te maken', ' oven']
# appliances                                                           []
# type                                                        ['lasagne']
# Name: 3749, dtype: object
#
#
# id                                                                66052
# title                                          ['lasagn', 'ratatouill']
# description           ['lasagn', 'ratatouill', ',', 'bechamelsaus', ...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'lasagneblad', 'bechamelsaus', '...
# calories                                                            810
# protein                                                              35
# carbohydrates                                                        77
# fat                                                                  38
# saturated_fat                                                        15
# sodium                                                             1660
# fiber                                                                10
# cooking_time                                                         20
# rating                                                                3
# review_count                                                         68
# recipe_instruction    Verwarm de oven voor op 200 °C. Bereid de béch...
# tags                                                           ['oven']
# appliances                            ['ovenschaal inhoud ca. 2 liter']
# type                                                        ['lasagne']
# Name: 11786, dtype: object
#
#
# id                                                               215934
# title                                         ['lasagn', 'oesterzwamm']
# description           ['italiaan', 'recept', '.', 'vegetarisch', 'ho...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'blauwaderkas', 'bechamelsaus', ...
# calories                                                            705
# protein                                                              34
# carbohydrates                                                        62
# fat                                                                  36
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                         65
# recipe_instruction                                                  NaN
# tags                             ['vegetarisch', ' oven', ' italiaans']
# appliances                   ['ovenschaal inhoud ca. 2 liter, ingevet']
# type                                                        ['lasagne']
# Name: 16714, dtype: object
#
#
# id                                                               609888
# title                                 ['lasagn', 'broccoli', 'amandel']
# description           ['romig', 'lasagn', 'broccoli', ',', 'ui', ','...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'port salut', 'bechamelsaus', 'm...
# calories                                                            595
# protein                                                              28
# carbohydrates                                                        55
# fat                                                                  29
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        131
# recipe_instruction                      Verwarm de oven voor op 200 °C.
# tags                             ['vegetarisch', ' oven', ' italiaans']
# appliances                            ['ovenschaal inhoud ca. 2 liter']
# type                                                        ['lasagne']
# Name: 11795, dtype: object
#
#
# id                                                               286300
# title                          ['lasagn', 'spinazie', 'gerookt', 'kip']
# description           ['lasagn', 'spinazie', ',', 'gorgonzola', 'ger...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['bladspinazie deelblokjes', 'bloem', 'boter',...
# calories                                                            590
# protein                                                              33
# carbohydrates                                                        53
# fat                                                                  26
# saturated_fat                                                        17
# sodium                                                              850
# fiber                                                                 4
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        232
# recipe_instruction    Verwarm de oven voor op 200 °C. Doe de bevoren...
# tags                                             ['oven', ' italiaans']
# appliances                                  ['ovenschaal (15 x 20 cm)']
# type                                                        ['lasagne']
# Name: 19179, dtype: object
#
#
# id                                                               674362
# title                                  ['lasagn', 'italiaan', 'groent']
# description           ['italiaan', 'pastaschotel', 'uit', 'oven', 'g...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'lasagneblad', 'geraspte kas', '...
# calories                                                            860
# protein                                                              36
# carbohydrates                                                        60
# fat                                                                  52
# saturated_fat                                                        23
# sodium                                                              910
# fiber                                                                 7
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        253
# recipe_instruction    Verwarm de oven voor op 190 °C. Verhit de olie...
# tags                         ['vooraf te maken', ' oven', ' italiaans']
# appliances                                  ['ovenschaal (20 x 25 cm)']
# type                                                        ['lasagne']
# Name: 5003, dtype: object
#
#
# id                                                               240254
# title                                    ['spinazielasagn', 'ansjovis']
# description           ['italiaan', 'recept', '.', 'hoofdgerecht', 'b...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'lasagneblad', 'gemalen belegen ...
# calories                                                            580
# protein                                                              27
# carbohydrates                                                        70
# fat                                                                  21
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         20
# rating                                                                3
# review_count                                                         66
# recipe_instruction                                                  NaN
# tags                                             ['oven', ' italiaans']
# appliances                   ['ovenschaal inhoud ca. 2 liter, ingevet']
# type                                                        ['lasagne']
# Name: 14244, dtype: object
#
#
# id                                                              1189003
# title                                       ['cannelloni', 'geitenkas']
# description           ['opgerold', 'lasagneblad', 'tomat', ',', 'cav...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['geitenkaas naturel in plakjes', 'verse lasag...
# calories                                                            590
# protein                                                              25
# carbohydrates                                                        52
# fat                                                                  29
# saturated_fat                                                        10
# sodium                                                              440
# fiber                                                                10
# cooking_time                                                         35
# rating                                                                3
# review_count                                                         13
# recipe_instruction     Snijd de knoflook fijn. Halveer de tomaatjes....
# tags                        ['zonder vlees/vis', ' oven', ' italiaans']
# appliances                                  ['ovenschaal (30 x 20 cm)']
# type                                                          ['pasta']
# Name: 2515, dtype: object
#
#
# id                                                               524736
# title                              ['lasagn', 'van', 'jamie', 'oliver']
# description           ['overher', 'lasagn', 'spek', ',', 'ui', ',', ...
# course                                                     hoofdgerecht
# recipe_yield                                                          6
# ingredients           ['olijfolie', 'mager gerookt ontbijtspek', 'cr...
# calories                                                            910
# protein                                                              37
# carbohydrates                                                        44
# fat                                                                  63
# saturated_fat                                                        30
# sodium                                                              725
# fiber                                                                 6
# cooking_time                                                         75
# rating                                                                3
# review_count                                                       5086
# recipe_instruction    Snijd het spek in kleine stukjes. Maak de uien...
# tags                           ['oven', ' italiaans', ' in te vriezen']
# appliances                ['aardewerken ovenschaal inhoud ca. 2 liter']
# type                                                        ['lasagne']
# Name: 3774, dtype: object
#
#
# id                                                                97246
# title                                                    ['zalmlasagn']
# description           ['heerlijk', 'lasagn', 'zalm', 'op', 'italiaan...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['gemalen belegen kas', 'gerookte zalmsnipper'...
# calories                                                            535
# protein                                                              32
# carbohydrates                                                        52
# fat                                                                  21
# saturated_fat                                                        11
# sodium                                                             1815
# fiber                                                                 2
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        264
# recipe_instruction    Verwarm de oven voor op 200 ºC. Schil de komko...
# tags                                             ['oven', ' italiaans']
# appliances                            ['ovenschaal inhoud ca. 2 liter']
# type                                                        ['lasagne']
# Name: 13029, dtype: object
#
#
# id                                                               232994
# title                                      ['lasagn', 'witlof', 'zalm']
# description           ['romig', 'lasagn', 'zalm', ',', 'witlof', 'mo...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['gerookte zalmsnipper', 'bechamelsaus', 'melk...
# calories                                                            550
# protein                                                              35
# carbohydrates                                                        60
# fat                                                                  18
# saturated_fat                                                         9
# sodium                                                             1685
# fiber                                                                 4
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        183
# recipe_instruction                                                  NaN
# tags                                             ['oven', ' italiaans']
# appliances                          ['ovenschaal (inhoud ca. 2 1/2 l)']
# type                                                        ['lasagne']
# Name: 17960, dtype: object
#
#
# id                                                               377936
# title                                              ['lasagn', 'groent']
# description           ['lasagn', 'winterpen', ',', 'venkel', ',', 's...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['winterpen', 'olijfolie', 'melk', 'venkelknol...
# calories                                                            890
# protein                                                              32
# carbohydrates                                                        53
# fat                                                                  57
# saturated_fat                                                        32
# sodium                                                             1140
# fiber                                                                 9
# cooking_time                                                         30
# rating                                                                3
# review_count                                                        114
# recipe_instruction    Verwarm de oven voor op 200 ºC. Halveer de ven...
# tags                                             ['oven', ' italiaans']
# appliances                      ['wok', 'lage ovenschaal (20 x 25 cm)']
# type                                                        ['lasagne']
# Name: 8704, dtype: object
#
#
# id                                                               775522
# title                                                ['pompoenravioli']
# description           ['recept', '.', 'hoofdgerecht', 'bevat', 'volg...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'tomatenblokjes', 'geraspte parm...
# calories                                                            435
# protein                                                              18
# carbohydrates                                                        44
# fat                                                                  21
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         40
# rating                                                                3
# review_count                                                        139
# recipe_instruction    Verhit de olie in een pan en fruit de knoflook...
# tags                                                ['kerst', ' koken']
# appliances                                               ['staafmixer']
# type                                                          ['pasta']
# Name: 13649, dtype: object
#
#
# id                                                               704276
# title                                                        ['lasagn']
# description                      ['lasagn', 'wokgroent', 'gehakt', '.']
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['lasagneblad', 'pastasaus sugo casa', 'paprik...
# calories                                                            600
# protein                                                              42
# carbohydrates                                                        52
# fat                                                                  24
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         10
# rating                                                                2
# review_count                                                        448
# recipe_instruction    Verwarm de oven voor op 200 °C. Bak het gehakt...
# tags                     ['oven', ' italiaans', ' wat eten we vandaag']
# appliances                                  ['ovenschaal (25 x 30 cm)']
# type                                                        ['lasagne']
# Name: 17359, dtype: object
#
#
# id                                                              1178194
# title                 ['ver', 'lasagn', 'courget', 'romig', 'mozzare...
# description           ['lasagn', 'tomatensaus', ',', 'courget', ',',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['hamblokjes', 'verse lasagneblad', 'passata d...
# calories                                                            640
# protein                                                              40
# carbohydrates                                                        59
# fat                                                                  26
# saturated_fat                                                        14
# sodium                                                             1560
# fiber                                                                 5
# cooking_time                                                         10
# rating                                                                2
# review_count                                                        137
# recipe_instruction    Verwarm de oven voor op 200 °C. Was de courget...
# tags                     ['oven', ' italiaans', ' wat eten we vandaag']
# appliances                                  ['ovenschaal (30 x 20 cm)']
# type                                                        ['lasagne']
# Name: 9309, dtype: object
#
#
# id                                                               607058
# title                                      ['lasagn', 'van', 'pompoen']
# description           ['ovengerecht', 'pompoen', 'als', 'lasagneblad...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['bloem', 'lasagneblad', 'boter', 'melk', 'ger...
# calories                                                            540
# protein                                                              22
# carbohydrates                                                        57
# fat                                                                  24
# saturated_fat                                                        15
# sodium                                                              815
# fiber                                                                 4
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        246
# recipe_instruction    Snijd de pompoen in kwarten. Verwijder de zade...
# tags                     ['vegetarisch', ' vooraf te maken', ' budget']
# appliances                                  ['ovenschaal (25 x 25 cm)']
# type                                                        ['lasagne']
# Name: 14273, dtype: object
#
#
# id                                                               759062
# title                           ['italiaan', '-', 'amerikan', 'lasagn']
# description           ['italiaan', 'pastagerecht', 'uit', 'oven', 'a...
# course                                                     hoofdgerecht
# recipe_yield                                                          6
# ingredients           ['bloem', 'tomatenblokjes', 'bleekselderij', '...
# calories                                                            625
# protein                                                              32
# carbohydrates                                                        47
# fat                                                                  33
# saturated_fat                                                        17
# sodium                                                              960
# fiber                                                                 5
# cooking_time                                                         45
# rating                                                                3
# review_count                                                        378
# recipe_instruction    Verwarm de oven voor op 200 °C. Snipper de uie...
# tags                           ['oven', ' italiaans', ' in te vriezen']
# appliances                                  ['ovenschaal (24 x 35 cm)']
# type                                                        ['lasagne']
# Name: 12433, dtype: object
#
#
# id                                                               818442
# title                        ['pappardell', 'groen', 'asperges', 'ham']
# description           ['italiaan', 'recept', '.', 'hoofdgerecht', 'b...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie extra vierg', 'pijnboompit', 'vers...
# calories                                                            800
# protein                                                              36
# carbohydrates                                                        76
# fat                                                                  38
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                         78
# recipe_instruction    Verwijder de houtachtige onderkant van de aspe...
# tags                                          ['italiaans', ' grillen']
# appliances                                                 ['grillpan']
# type                                                          ['vlees']
# Name: 14897, dtype: object
#
#
# id                                                               830980
# title                                                  ['lasagnesalad']
# description           ['italiaan', 'recept', '.', 'hoofdgerecht', 'b...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'lasagneblad', 'knoflok', 'zout'...
# calories                                                            740
# protein                                                              29
# carbohydrates                                                        53
# fat                                                                  46
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                        227
# recipe_instruction    Maak in een ruime schaal een marinade van het ...
# tags                    ['italiaans', ' wat eten we vandaag', ' koken']
# appliances                                                           []
# type                                                         ['salade']
# Name: 1912, dtype: object
#
#
# id                                                              1187284
# title                              ['rijkgevuld', 'lasagn', 'grillkas']
# description           ['ver', 'lasagneblad', 'gegrild', 'groent', 's...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['tomatenblokjes', 'knoflok', 'verse lasagnebl...
# calories                                                            590
# protein                                                              25
# carbohydrates                                                        48
# fat                                                                  32
# saturated_fat                                                         3
# sodium                                                              335
# fiber                                                                 7
# cooking_time                                                         16
# rating                                                                3
# review_count                                                         15
# recipe_instruction    Verwarm de oven voor op 180 °C. Laat de gegril...
# tags                        ['zonder vlees/vis', ' oven', ' italiaans']
# appliances                                  ['ovenschaal (20 x 30 cm)']
# type                                                        ['lasagne']
# Name: 702, dtype: object
#
#
# id                                                               523990
# title                        ['groen', 'lasagn', 'garnal', 'pestosaus']
# description           ['groen', 'lasagn', 'spinazie', ',', 'rom', ',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['gehakte spinazie', 'komkommer', 'kookroom li...
# calories                                                            580
# protein                                                              31
# carbohydrates                                                        51
# fat                                                                  28
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                        162
# recipe_instruction                      Verwarm de oven voor op 180 °C.
# tags                                             ['oven', ' italiaans']
# appliances                                               ['ovenschaal']
# type                                                        ['lasagne']
# Name: 11219, dtype: object
#
#
# id                                                               669400
# title                 ['lasagn', 'van', 'knolselderij', ',', 'appel'...
# description           ['recept', '.', 'voorgerecht', 'bevat', 'volge...
# course                                                      voorgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie extra vierg', 'sjalot', 'balsamico...
# calories                                                            210
# protein                                                              17
# carbohydrates                                                        13
# fat                                                                  10
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# ...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['lasagneblad', 'geraspte kas', 'kastanjechamp...
# calories                                                            580
# protein                                                              33
# carbohydrates                                                        40
# fat                                                                  32
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                         47
# recipe_instruction                                                  NaN
# tags                             ['vegetarisch', ' oven', ' italiaans']
# appliances            ['4 vierkante ovenschoteltjes (20 x 20 cm),\n\...
# type                                                        ['lasagne']
# Name: 6115, dtype: object
#
#
# id                                                              1188649
# title                                 ['panlasagn', 'ver', 'pastasaus']
# description           ['lasagn', 'uit', 'pan', 'van', 'rundergehakt'...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['verse lasagneblad', 'knoflok', 'verse tomaat...
# calories                                                            560
# protein                                                              33
# carbohydrates                                                        52
# fat                                                                  23
# saturated_fat                                                        10
# sodium                                                              440
# fiber                                                                 8
# cooking_time                                                         30
# rating                                                                4
# review_count                                                         26
# recipe_instruction    Verhit een grote hapjespan zonder olie of bote...
# tags                                                      ['italiaans']
# appliances                                                           []
# type                                                          ['pasta']
# Name: 11077, dtype: object
#
#
# id                                                              1185743
# title                               ['courget', '-', 'auberginelasagn']
# description           ['lasagn', 'van', 'courgettes', ',', 'aubergin...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['bloem', 'geurloze kokosolie', 'sojadrink ong...
# calories                                                            610
# protein                                                              15
# carbohydrates                                                        32
# fat                                                                  45
# saturated_fat                                                         7
# sodium                                                              635
# fiber                                                                 8
# cooking_time                                                         45
# rating                                                                3
# review_count                                                        186
# recipe_instruction    Verwarm de oven voor op 180 °C. Ris de naadjes...
# tags                          ['lactosevrij', ' veganistisch', ' oven']
# appliances                                  ['ovenschaal (20 x 30 cm)']
# type                                                        ['lasagne']
# Name: 11733, dtype: object
#
#
# id                                                               767208
# title                                          ['lasagn', 'ratatouill']
# description           ['lasagn', 'tomat', ',', 'ui', ',', 'knoflok',...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'tomatenblokjes', 'knoflok', 've...
# calories                                                            645
# protein                                                              23
# carbohydrates                                                        52
# fat                                                                  38
# saturated_fat                                                        16
# sodium                                                              720
# fiber                                                                 5
# cooking_time                                                         10
# rating                                                                3
# review_count                                                        385
# recipe_instruction    Verwarm de oven voor op 180 °C. Snipper de ui,...
# tags                       ['vegetarisch', ' vooraf te maken', ' oven']
# appliances                                  ['ovenschaal (20 x 30 cm)']
# type                                                        ['lasagne']
# Name: 4322, dtype: object
#
#
# id                                                               577906
# title                              ['lasagn', 'champignon', 'spinazie']
# description           ['vegetarisch', 'italiaan', 'gerecht', 'ui', '...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'bloem', 'champignon', 'volle me...
# calories                                                            535
# protein                                                              23
# carbohydrates                                                        62
# fat                                                                  20
# saturated_fat                                                         5
# sodium                                                              110
# fiber                                                                 8
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        361
# recipe_instruction    Verwarm de oven voor op 200 °C. Snipper de ui....
# tags                       ['vegetarisch', ' vooraf te maken', ' oven']
# appliances                                          ['ovenschaal (2l)']
# type                                                        ['lasagne']
# Name: 3066, dtype: object
#
#
# id                                                              1186102
# title                    ['open', 'lasagn', 'asperges', 'blauwaderkas']
# description           ['lasagn', 'uit', 'pan', 'blauwaderkas', ',', ...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'verse lasagneblad', 'walnot', '...
# calories                                                            680
# protein                                                              19
# carbohydrates                                                        65
# fat                                                                  37
# saturated_fat                                                        15
# sodium                                                              215
# fiber                                                                 7
# cooking_time                                                         25
# rating                                                                3
# review_count                                                         43
# recipe_instruction    Verwijder de houtachtige onderkant van de aspe...
# tags                            ['vegetarisch', ' italiaans', ' koken']
# appliances                                                           []
# type                                                        ['lasagne']
# Name: 16047, dtype: object
#
#
# id                                                              1185577
# title                                    ['lasagn', 'zalm', 'spinazie']
# description           ['lasagneschotel', 'spinazie', ',', 'zalm', 't...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['roomkaas kruid', 'wilde zalmfilet', 'spinazi...
# calories                                                            580
# protein                                                              38
# carbohydrates                                                        52
# fat                                                                  23
# saturated_fat                                                        11
# sodium                                                             1200
# fiber                                                                 8
# cooking_time                                                         20
# rating                                                                3
# review_count                                                        513
# recipe_instruction    Verwarm de oven voor op 180 °C. Verhit de spin...
# tags                              ['glutenvrij', ' oven', ' italiaans']
# appliances                                                           []
# type                                                        ['lasagne']
# Name: 19736, dtype: object
#
#
# id                                                               560858
# title                             ['cannelloni', 'ricotta', 'spinazie']
# description           ['cannelloni', 'ricotta', ',', 'spinazie', ','...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['olijfolie', 'lasagneblad', 'spinazie', 'rico...
# calories                                                            555
# protein                                                              32
# carbohydrates                                                        35
# fat                                                                  32
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         15
# rating                                                                3
# review_count                                                        312
# recipe_instruction    Verwarm de oven voor op 200 °C. Snijd de knofl...
# tags                        ['zonder vlees/vis', ' oven', ' italiaans']
# appliances                        ['rechthoekige bakvorm (20 x 30 cm)']
# type                                                          ['pasta']
# Name: 6150, dtype: object
#
#
# id                                                               704172
# title                 ['lazy', 'lasagn', 'van', 'knolselderij', 'pom...
# description           ['lasagn', 'pompoen', ',', 'prei', ',', 'katen...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['dunne prei', 'grana padano, snipper', 'volle...
# calories                                                            425
# protein                                                              17
# carbohydrates                                                        10
# fat                                                                  34
# saturated_fat                                                        20
# sodium                                                              410
# fiber                                                                 5
# cooking_time                                                         20
# rating                                                                2
# review_count                                                         80
# recipe_instruction    Verwarm de oven voor op 200 °C. Schil de knols...
# tags                                            ['glutenvrij', ' oven']
# appliances                      ['rechthoekige ovenschaal (inh. 1.5l)']
# type                                                        ['lasagne']
# Name: 4951, dtype: object
#
#
# id                                                               385192
# title                                                 ['groentelasagn']
# description           ['lasagn', 'courget', ',', 'aubergin', ',', 'r...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['gezeefde tomat', 'bloem', 'geraspte belegen ...
# calories                                                            630
# protein                                                              35
# carbohydrates                                                        71
# fat                                                                  23
# saturated_fat                                                         0
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         30
# rating                                                                3
# review_count                                                        108
# recipe_instruction    Snijd de courgette en aubergine in blokjes en ...
# tags                                             ['oven', ' italiaans']
# appliances                         ['ronde ovenschaal (ca. 2.5 liter)']
# type                                                        ['lasagne']
# Name: 13573, dtype: object
#
#
# id                                                               712884
# title                          ['chines', 'lasagn', 'gehakt', 'garnal']
# description           ['chines', 'recept', '.', 'hoofdgerecht', 'bev...
# course                                                     hoofdgerecht
# recipe_yield                                                          4
# ingredients           ['eiwit', 'roze garnal', 'bosuitjes', 'gehakt'...
# calories                                                            365
# protein                                                              27
# carbohydrates                                                        31
# fat                                                                  15
# saturated_fat                                                       NaN
# sodium                                                              NaN
# fiber                                                               NaN
# cooking_time                                                         25
# rating                                                                3
# review_count                                                         48
# recipe_instruction    Pureer in de keukenmachine het gehakt met de g...
# tags                                 ['oven', ' aziatisch', ' chinees']
# appliances            ['aluminiumfolie, kleine rechthoekige ovenscha...
# type                                                        ['lasagne']
# Name: 16671, dtype: object
